# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')
# import pandas_datareader as pdr

from datetime import datetime


warnings.filterwarnings('ignore')

# %% [markdown]
# The data can either be accessed using a <b>pandas_datareader</b> library or be downloaded directly in .csv formaat using the url https://finance.yahoo.com/quote/MSFT/history?period1=1516233600&period2=1674000000&interval=1d&filter=history&frequency=1d&includeAdjustedClose=true.
#
# Since currently yahoo have made some changes in their API, the code `pdr.get_data_yahoo('MSFT')` is unable to fetch the data, so we'll be working by downloading the data in csv format from the above url.

# %%
# pdr.get_data_yahoo('MSFT')

# %%
df = pd.read_csv('MSFT.csv', parse_dates=['Date'])
df.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close    Volume
# 0 2017-01-18  62.669998  62.700001  62.119999  62.500000  57.571678  19670100
# 1 2017-01-19  62.240002  62.980000  62.200001  62.299999  57.387444  18451700
# 2 2017-01-20  62.669998  62.820000  62.369999  62.740002  57.792763  30213500
# 3 2017-01-23  62.700001  63.119999  62.570000  62.959999  57.995399  23097600
# 4 2017-01-24  63.200001  63.740002  62.939999  63.520000  58.511246  24672900

# %%
df.tail()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 1505 2023-01-10  227.759995  231.309998  227.330002  228.850006  228.850006
# 1506 2023-01-11  231.289993  235.949997  231.110001  235.770004  235.770004
# 1507 2023-01-12  235.259995  239.899994  233.559998  238.509995  238.509995
# 1508 2023-01-13  237.000000  239.369995  234.919998  239.229996  239.229996
# 1509 2023-01-17  237.970001  240.910004  237.089996  240.350006  240.350006
#
#         Volume
# 1505  27033900
# 1506  28669300
# 1507  27269500
# 1508  21317700
# 1509  29831300

# %%
df.set_index('Date', inplace=True)

# %%
df.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1510 entries, 2017-01-18 to 2023-01-17
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1510 non-null   float64
#  1   High       1510 non-null   float64
#  2   Low        1510 non-null   float64
#  3   Close      1510 non-null   float64
#  4   Adj Close  1510 non-null   float64
#  5   Volume     1510 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 82.6 KB

# %%
df[df.isna().any(1)]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %% [markdown]
# None of the columns has <b>NAN</b> values here. Also type conversion of column values is not needed.

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.plot(figsize=(12,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
fig, ax = plt.subplots(4, 1, figsize=(12,20), sharex=True)

df['Open'].plot(ax=ax[0], title='Microsoft stock opening share value')
df['High'].plot(ax=ax[1], title='Microsoft stock high share value')
df['Low'].plot(ax=ax[2], title='Microsoft stock low share value')
df['Close'].plot(ax=ax[3], title='Microsoft stock closing share value')
# Out:
# <AxesSubplot:title={'center':'Microsoft stock closing share value'}, xlabel='Date'>

# %%
# let's visualize only the part of the graph on which the microsoft value goes up really high
fig, ax = plt.subplots(4, 1, figsize=(12,20), sharex=True, sharey=False)
plt.ylabel('Price USD($)')
# fig.autofmt_xdate()
# plt.tight_layout()

df['Open'].plot(ax=ax[0], xlim=['2020-12-01', '2023-01-01'], title='Microsoft stock opening share value')
df['High'].plot(ax=ax[1], xlim=['2020-12-01', '2023-01-01'], title='Microsoft stock high share value')
df['Low'].plot(ax=ax[2], xlim=['2020-12-01', '2023-01-01'], title='Microsoft stock low share value')
df['Close'].plot(ax=ax[3], xlim=['2020-12-01', '2023-01-01'], title='Microsoft stock closing share value')
# Out:
# <AxesSubplot:title={'center':'Microsoft stock closing share value'}, xlabel='Date', ylabel='Price USD($)'>

# %% [markdown]
# ## Time Resampling
# ### Upsampling

# %%
annual_stock = df.resample('A').max()
display(annual_stock)

annual_stock['Close'].plot()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-12-31   87.120003   87.500000   86.230003   86.849998   81.787941
# 2018-12-31  115.419998  116.180000  114.930000  115.610001  110.279938
# 2019-12-31  159.449997  159.550003  158.220001  158.960007  154.538162
# 2020-12-31  229.270004  232.860001  227.350006  231.649994  226.997528
# 2021-12-31  344.619995  349.670013  342.200012  343.109985  339.924805
# 2022-12-31  335.350006  338.000000  329.779999  334.750000  331.642426
# 2023-12-31  243.080002  245.750000  237.399994  240.350006  240.350006
#
#                Volume
# Date
# 2017-12-31   71066700
# 2018-12-31  111242100
# 2019-12-31   55636400
# 2020-12-31   97012700
# 2021-12-31   69870600
# 2022-12-31   90428900
# 2023-12-31   50623400
# <AxesSubplot:xlabel='Date'>

# %%
annual_stock['Close'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
annual_stock['Volume'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
quarterly_stock = df.resample('QS').max()
display(quarterly_stock.tail(10))
quarterly_stock['Close'].plot()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-10-01  226.309998  228.119995  223.580002  224.960007  221.019012
# 2021-01-01  245.029999  246.130005  242.919998  244.990005  240.698090
# 2021-04-01  270.690002  271.649994  269.600006  271.399994  267.876678
# 2021-07-01  305.019989  305.839996  302.000000  305.220001  301.834412
# 2021-10-01  344.619995  349.670013  342.200012  343.109985  339.924805
# 2022-01-01  335.350006  338.000000  329.779999  334.750000  331.642426
# 2022-04-01  313.269989  315.109985  309.869995  314.970001  312.691284
# 2022-07-01  291.989990  294.179993  290.420013  293.470001  292.025421
# 2022-10-01  261.690002  263.920013  254.309998  257.220001  257.220001
# 2023-01-01  243.080002  245.750000  237.399994  240.350006  240.350006
#
#               Volume
# Date
# 2020-10-01  63354900
# 2021-01-01  69870600
# 2021-04-01  46903100
# 2021-07-01  43186200
# 2021-10-01  52588700
# 2022-01-01  90428900
# 2022-04-01  63477700
# 2022-07-01  45994000
# 2022-10-01  86102000
# 2023-01-01  50623400
# <AxesSubplot:xlabel='Date'>

# %%
quarterly_stock['Close'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
monthly_stock = df.resample('M').max()
display(monthly_stock.head())

monthly_stock['Close'].plot()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2017-01-31  65.690002  65.910004  64.889999  65.779999  60.593033  44818000
# 2017-02-28  64.739998  65.239998  64.449997  64.720001  59.885384  45827000
# 2017-03-31  65.650002  66.190002  65.449997  65.860001  61.034527  49219700
# 2017-04-30  68.910004  69.139999  67.690002  68.459999  63.444038  39548800
# 2017-05-31  70.529999  70.739998  69.809998  70.410004  65.625160  34956000
# <AxesSubplot:xlabel='Date'>

# %%
monthly_stock['Close'].plot(kind='bar', figsize=(14,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# After exploring and visualizing the above plote we can notice that there is some upward and downward trend in our dataset. Most probably the dataset is not stationary.

# %% [markdown]
# # Stationarity Check
# ## Summary statistics and plot
# Though this is not the most rigorous method to check the stationarity of the data, it gives a good sense of whether the data is stationary or not.

# %%
df['Close'].hist()
# Out:
# <AxesSubplot:>

# %%
chunks = np.split(df['Close'], indices_or_sections=10)
print('Mean: ', np.mean(chunks, axis=1))
print('\nVariance: ',np.var(chunks, axis=1))
# Out:
# Mean:  [ 68.03966922  84.41152331 103.64410611 113.69966901 142.99715238
#  182.66649026 221.16807929 277.52960237 302.22841033 250.99344336]
#
# Variance:  [ 11.59197866  49.8547398   46.5124306   88.96238242  71.38420441
#  405.25823545 139.67014173 525.42642763 629.28894424 303.87170849]

# %% [markdown]
# To get even more sophisticated understanding of the change in mean and variance let's plot the histogram of mean and variance.

# %%
pd.Series(np.mean(chunks, axis=1)).hist();

# %%
pd.Series(np.var(chunks, axis=1)).hist();

# %% [markdown]
# For a data to be stationary, it should have constant mean and variance across the time series. But in case of our dataset, the mean and the variance is changing drastically over time which means that out data is not stationary.
#
# As this is not an accurate way to check for the stationarity of the data, let's use some statistical tests like <b>Augmeted Dickey-Fuller Test</b> to check for the stationarity.
# ### Augmented Dickey-Fuller (ADF) Test
# adfuller() returns adf, pvalue, usedlag, nobs, critical_values, icbest<br>
# <b>Null Hypothesis</b>: Series is not stationary.<br>
# <b>Alternative Hypothesis</b>: Series is stationary.<br>
# 1. If p-value < threshold, reject null hyppothesis.<br>
# 2. If p-value ≥ threshold, accept null hypothesis. <br>
#
# Generally, we take <b>0.05</b> as a threshold value.

# %%
from statsmodels.tsa.stattools import adfuller

adf, pvalue, usedlag, nobs, critical_values, icbest = adfuller(df['Close'])

# %%
def adf_test(timeseries):
    test_stat = adfuller(timeseries)
    result = pd.Series({'ADF statistic': test_stat[0],
                       'p-value': test_stat[1],
                        'Used lags': test_stat[2],
                        'Observations used': test_stat[3]})
    for key, value in test_stat[4].items():
        result['Critical value ({})'.format(key)] = value
    if test_stat[1] < 0.05:
        print("\nReject null hypothesis! Indicates that the data is stationary.")
    else:
        print("\nAccept null hypothesis! Indicates that the data is not stationary.")
    return result

# %%
adf_test(df['Close'])
# Out:
# Accept null hypothesis! Indicates that the data is not stationary.
# ADF statistic             -1.144897
# p-value                    0.696840
# Used lags                  9.000000
# Observations used       1500.000000
# Critical value (1%)       -3.434717
# Critical value (5%)       -2.863469
# Critical value (10%)      -2.567797
# dtype: float64

# %% [markdown]
# ### Kwiatkowski-Phillips-Schmidt-Shin (KPSS) Test
# ADF and KPSS has just opposite assumption. A key difference from ADF test is the null hypothesis of the KPSS test is that the series is stationary.<br><br>
# <b>Null Hypothesis</b>: Series is stationary.<br>
# <b>Alternative Hypothesis</b>: Series is not stationary.<br>
# 1. If p-value < threshold, reject null hyppothesis.<br>
# 2. If p-value ≥ threshold, accept null hypothesis. <br>
#
# Generally, we take <b>0.05</b> as a threshold value.
#
# kpss() returns kpss_stat, p_value, lags, crit

# %%
from statsmodels.tsa.stattools import kpss

kpss_stat, p_value, lags, crit = kpss(df['Close']);
# Out:
# /home/sushmita/anaconda3/envs/tfEnv/lib/python3.10/site-packages/statsmodels/tsa/stattools.py:2018: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(

# %%
def kpss_test(timeseries):
    test_stat = kpss(timeseries)
    result = pd.Series({'KPSS statistic': test_stat[0],
                       'p-value': test_stat[1],
                        'Used lags': test_stat[2]})
    for key, value in test_stat[3].items():
        result['Critical value ({})'.format(key)] = value
    if test_stat[1] < 0.05:
        print("\nReject null hypothesis! Indicates that the data is not stationary.")
    else:
        print("\nAccept null hypothesis! Indicates that the data is stationary.")
    return result

# %%
kpss_test(df['Close'])
# Out:
# Reject null hypothesis! Indicates that the data is not stationary.
# /home/sushmita/anaconda3/envs/tfEnv/lib/python3.10/site-packages/statsmodels/tsa/stattools.py:2018: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(
# KPSS statistic            5.54623
# p-value                   0.01000
# Used lags                25.00000
# Critical value (10%)      0.34700
# Critical value (5%)       0.46300
# Critical value (2.5%)     0.57400
# Critical value (1%)       0.73900
# dtype: float64

# %% [markdown]
# Both tests <b>ADF</b> and <b>KPSS</b> conclude that our data is not stationary

# %% [markdown]
# ## Smoothing
# ## Simple Moving Average

# %%
# df.drop('Open: 15 days rolling', axis=1, inplace=True)

# %%
df['Close: 15 days rolling'] = df['Close'].rolling(window=15, min_periods=2).mean()
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2017-01-18  62.669998  62.700001  62.119999  62.500000  57.571678  19670100
# 2017-01-19  62.240002  62.980000  62.200001  62.299999  57.387444  18451700
# 2017-01-20  62.669998  62.820000  62.369999  62.740002  57.792763  30213500
# 2017-01-23  62.700001  63.119999  62.570000  62.959999  57.995399  23097600
# 2017-01-24  63.200001  63.740002  62.939999  63.520000  58.511246  24672900
#
#             Close: 15 days rolling
# Date
# 2017-01-18                     NaN
# 2017-01-19               62.399999
# 2017-01-20               62.513334
# 2017-01-23               62.625000
# 2017-01-24               62.804000

# %%
df[['Close', 'Close: 15 days rolling']].plot(figsize=(12,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
adf_test(df['Close: 15 days rolling'].fillna(0))
# Out:
# Accept null hypothesis! Indicates that the data is not stationary.
# ADF statistic             -1.178981
# p-value                    0.682572
# Used lags                 23.000000
# Observations used       1486.000000
# Critical value (1%)       -3.434758
# Critical value (5%)       -2.863487
# Critical value (10%)      -2.567807
# dtype: float64

# %%
df['Close: 30 days rolling'] = df['Close'].rolling(window=30, min_periods=2).mean()
df['Close: 60 days rolling'] = df['Close'].rolling(window=60, min_periods=2).mean()

# %%
df[['Close', 'Close: 15 days rolling', 
    'Close: 30 days rolling','Close: 60 days rolling']].plot(xlim=['2019-12-01', '2023-01-01'],figsize=(12,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
adf_test(df['Close: 60 days rolling'].fillna(0))
# Out:
# Accept null hypothesis! Indicates that the data is not stationary.
# ADF statistic             -1.218854
# p-value                    0.665433
# Used lags                 10.000000
# Observations used       1499.000000
# Critical value (1%)       -3.434720
# Critical value (5%)       -2.863470
# Critical value (10%)      -2.567798
# dtype: float64

# %% [markdown]
# ## Cumulative Moving Average
# Replacing each data point in each time series by the average of the previous data points in the same time series.

# %%
df['Close'].expanding().mean().plot(figsize=(12,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Exponential Moving Average

# %%
# exponential moving average
# alpha here is smoothening parameter
df['EWM_0.1'] = df['Close'].ewm(alpha=0.1, adjust=False).mean()
df['EWM_0.3'] = df['Close'].ewm(alpha=0.3, adjust=False).mean()

df[['Close', 'EWM_0.1', 'EWM_0.3']].plot(figsize=(12,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Line with smoothening parameter (alpha) 0.3 is looking better than 0.1 as it is more towards the original data points.

# %%
# df.drop(['EWMA_5days', 'EWMA_10days'], inplace=True, axis=1)

# %%
# exponential weighted moving average of 5 days
# we're calculating EWMA by specifying span parameter in ewm() function
df['EWMA_5days'] = df['Close'].ewm(span=5).mean()

df[['Close', 'EWM_0.3', 'EWMA_5days']].plot(figsize=(12,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
adf_test(df['EWMA_5days'])
# Out:
# Accept null hypothesis! Indicates that the data is not stationary.
# ADF statistic             -1.136932
# p-value                    0.700122
# Used lags                 10.000000
# Observations used       1499.000000
# Critical value (1%)       -3.434720
# Critical value (5%)       -2.863470
# Critical value (10%)      -2.567798
# dtype: float64

# %% [markdown]
# Here we see that our data is still not stationary. So to make it stationary we'll use differencing.
# ## Differencing

# %%
df['Close - First order difference'] = df['Close'] - df['Close'].shift(1)

# %%
df['Close - First order difference'].head()
# Out:
# Date
# 2017-01-18         NaN
# 2017-01-19   -0.200001
# 2017-01-20    0.440003
# 2017-01-23    0.219997
# 2017-01-24    0.560001
# Name: Close - First order difference, dtype: float64

# %%
adf_test(df['Close - First order difference'].dropna())
# Out:
# Reject null hypothesis! Indicates that the data is stationary.
# ADF statistic          -1.314485e+01
# p-value                 1.405134e-24
# Used lags               8.000000e+00
# Observations used       1.500000e+03
# Critical value (1%)    -3.434717e+00
# Critical value (5%)    -2.863469e+00
# Critical value (10%)   -2.567797e+00
# dtype: float64

# %%
kpss_test(df['Close - First order difference'].dropna())
# Out:
# Accept null hypothesis! Indicates that the data is stationary.
# /home/sushmita/anaconda3/envs/tfEnv/lib/python3.10/site-packages/statsmodels/tsa/stattools.py:2022: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(
# KPSS statistic           0.127471
# p-value                  0.100000
# Used lags                5.000000
# Critical value (10%)     0.347000
# Critical value (5%)      0.463000
# Critical value (2.5%)    0.574000
# Critical value (1%)      0.739000
# dtype: float64

# %% [markdown]
# So after first order differecing both test statistics are saying that our series is stationary.

# %%
df['Close - First order difference'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Close - First order difference'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# On the above histogram we see that the series is following normal distribution after making it stationary. If the variables in the series follows gaussian distribution then the series is called Gaussian White Noise, it is random....It means all variables are independently and identically distributed with mean 0 and the same variance. Each values has 0 correlation with all other values in the series. Such data cannot be modeled and prediction cannot be made using them.

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(df['Close - First order difference']);

# %%
plot_pacf(df['Close - First order difference']);

# %% [markdown]
# ## Time Series Decomposition
# Decomposition of time series into 3 components
# 1. Trend
# 2. Seasonality
# 3. Residual

# %%
df['Close'].plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
print(df.index.freq)
# Out:
# None

# %%
[type(df.index), df.index.dtype]
# Out:
# [pandas.core.indexes.datetimes.DatetimeIndex, dtype('<M8[ns]')]

# %%
print(df.index.inferred_freq)
# Out:
# None

# %%
# Standardizing the DatetimeIndex
# The frequency of the DateTime index is None so we've to set it to some datetime period
# Our datetime index has some missing days (weekend days- saturday and sunday along with some other missing dates)
# So we'll seet the frequency as 'B' business day and treat the missing values using fillna() functio
new_index = df.asfreq('B').index
new_index
# Out:
# DatetimeIndex(['2017-01-18', '2017-01-19', '2017-01-20', '2017-01-23',
#                '2017-01-24', '2017-01-25', '2017-01-26', '2017-01-27',
#                '2017-01-30', '2017-01-31',
#                ...
#                '2023-01-04', '2023-01-05', '2023-01-06', '2023-01-09',
#                '2023-01-10', '2023-01-11', '2023-01-12', '2023-01-13',
#                '2023-01-16', '2023-01-17'],
#               dtype='datetime64[ns]', name='Date', length=1565, freq='B')

# %%
df_new = df.reindex(new_index, fill_value=np.NAN)

# %%
print(df_new.index.freq)
# Out:
# <BusinessDay>

# %%
df_new.shape[0] - df.shape[0]
# Out:
# 55

# %%
df_new[df_new.isna().any(1)]
# Out:
#                  Open       High        Low  Close  Adj Close      Volume  \
# Date
# 2017-01-18  62.669998  62.700001  62.119999   62.5  57.571678  19670100.0
# 2017-02-20        NaN        NaN        NaN    NaN        NaN         NaN
# 2017-04-14        NaN        NaN        NaN    NaN        NaN         NaN
# 2017-05-29        NaN        NaN        NaN    NaN        NaN         NaN
# 2017-07-04        NaN        NaN        NaN    NaN        NaN         NaN
# 2017-09-04        NaN        NaN        NaN    NaN        NaN         NaN
# 2017-11-23        NaN        NaN        NaN    NaN        NaN         NaN
# 2017-12-25        NaN        NaN        NaN    NaN        NaN         NaN
# 2018-01-01        NaN        NaN        NaN    NaN        NaN         NaN
# 2018-01-15        NaN        NaN        NaN    NaN        NaN         NaN
# 2018-02-19        NaN        NaN        NaN    NaN        NaN         NaN
# 2018-03-30        NaN        NaN        NaN    NaN        NaN         NaN
# 2018-05-28        NaN        NaN        NaN    NaN        NaN         NaN
# 2018-07-04        NaN        NaN        NaN    NaN        NaN         NaN
# 2018-09-03        NaN        NaN        NaN    NaN        NaN         NaN
# 2018-11-22        NaN        NaN        NaN    NaN        NaN         NaN
# 2018-12-05        NaN        NaN        NaN    NaN        NaN         NaN
# 2018-12-25        NaN        NaN        NaN    NaN        NaN         NaN
# 2019-01-01        NaN        NaN        NaN    NaN        NaN         NaN
# 2019-01-21        NaN        NaN        NaN    NaN        NaN         NaN
# 2019-02-18        NaN        NaN        NaN    NaN        NaN         NaN
# 2019-04-19        NaN        NaN        NaN    NaN        NaN         NaN
# 2019-05-27        NaN        NaN        NaN    NaN        NaN         NaN
# 2019-07-04        NaN        NaN        NaN    NaN        NaN         NaN
# 2019-09-02        NaN        NaN        NaN    NaN        NaN         NaN
# 2019-11-28        NaN        NaN        NaN    NaN        NaN         NaN
# 2019-12-25        NaN        NaN        NaN    NaN        NaN         NaN
# 2020-01-01        NaN        NaN        NaN    NaN        NaN         NaN
# 2020-01-20        NaN        NaN        NaN    NaN        NaN         NaN
# 2020-02-17        NaN        NaN        NaN    NaN        NaN         NaN
# 2020-04-10        NaN        NaN        NaN    NaN        NaN         NaN
# 2020-05-25        NaN        NaN        NaN    NaN        NaN         NaN
# 2020-07-03        NaN        NaN        NaN    NaN        NaN         NaN
# 2020-09-07        NaN        NaN        NaN    NaN        NaN         NaN
# 2020-11-26        NaN        NaN        NaN    NaN        NaN         NaN
# 2020-12-25        NaN        NaN        NaN    NaN        NaN         NaN
# 2021-01-01        NaN        NaN        NaN    NaN        NaN         NaN
# 2021-01-18        NaN        NaN        NaN    NaN        NaN         NaN
# 2021-02-15        NaN        NaN        NaN    NaN        NaN         NaN
# 2021-04-02        NaN        NaN        NaN    NaN        NaN         NaN
# 2021-05-31        NaN        NaN        NaN    NaN        NaN         NaN
# 2021-07-05        NaN        NaN        NaN    NaN        NaN         NaN
# 2021-09-06        NaN        NaN        NaN    NaN        NaN         NaN
# 2021-11-25        NaN        NaN        NaN    NaN        NaN         NaN
# 2021-12-24        NaN        NaN        NaN    NaN        NaN         NaN
# 2022-01-17        NaN        NaN        NaN    NaN        NaN         NaN
# 2022-02-21        NaN        NaN        NaN    NaN        NaN         NaN
# 2022-04-15        NaN        NaN        NaN    NaN        NaN         NaN
# 2022-05-30        NaN        NaN        NaN    NaN        NaN         NaN
# 2022-06-20        NaN        NaN        NaN    NaN        NaN         NaN
# 2022-07-04        NaN        NaN        NaN    NaN        NaN         NaN
# 2022-09-05        NaN        NaN        NaN    NaN        NaN         NaN
# 2022-11-24        NaN        NaN        NaN    NaN        NaN         NaN
# 2022-12-26        NaN        NaN        NaN    NaN        NaN         NaN
# 2023-01-02        NaN        NaN        NaN    NaN        NaN         NaN
# 2023-01-16        NaN        NaN        NaN    NaN        NaN         NaN
#
#             Close: 15 days rolling  Close: 30 days rolling  \
# Date
# 2017-01-18                     NaN                     NaN
# 2017-02-20                     NaN                     NaN
# 2017-04-14                     NaN                     NaN
# 2017-05-29                     NaN                     NaN
# 2017-07-04                     NaN                     NaN
# 2017-09-04                     NaN                     NaN
# 2017-11-23                     NaN                     NaN
# 2017-12-25                     NaN                     NaN
# 2018-01-01                     NaN                     NaN
# 2018-01-15                     NaN                     NaN
# 2018-02-19                     NaN                     NaN
# 2018-03-30                     NaN                     NaN
# 2018-05-28                     NaN                     NaN
# 2018-07-04                     NaN                     NaN
# 2018-09-03                     NaN                     NaN
# 2018-11-22                     NaN                     NaN
# 2018-12-05                     NaN                     NaN
# 2018-12-25                     NaN                     NaN
# 2019-01-01                     NaN                     NaN
# 2019-01-21                     NaN                     NaN
# 2019-02-18                     NaN                     NaN
# 2019-04-19                     NaN                     NaN
# 2019-05-27                     NaN                     NaN
# 2019-07-04                     NaN                     NaN
# 2019-09-02                     NaN                     NaN
# 2019-11-28                     NaN                     NaN
# 2019-12-25                     NaN                     NaN
# 2020-01-01                     NaN                     NaN
# 2020-01-20                     NaN                     NaN
# 2020-02-17                     NaN                     NaN
# 2020-04-10                     NaN                     NaN
# 2020-05-25                     NaN                     NaN
# 2020-07-03                     NaN                     NaN
# 2020-09-07                     NaN                     NaN
# 2020-11-26                     NaN                     NaN
# 2020-12-25                     NaN                     NaN
# 2021-01-01                     NaN                     NaN
# 2021-01-18                     NaN                     NaN
# 2021-02-15                     NaN                     NaN
# 2021-04-02                     NaN                     NaN
# 2021-05-31                     NaN                     NaN
# 2021-07-05                     NaN                     NaN
# 2021-09-06                     NaN                     NaN
# 2021-11-25                     NaN                     NaN
# 2021-12-24                     NaN                     NaN
# 2022-01-17                     NaN                     NaN
# 2022-02-21                     NaN                     NaN
# 2022-04-15                     NaN                     NaN
# 2022-05-30                     NaN                     NaN
# 2022-06-20                     NaN                     NaN
# 2022-07-04                     NaN                     NaN
# 2022-09-05                     NaN                     NaN
# 2022-11-24                     NaN                     NaN
# 2022-12-26                     NaN                     NaN
# 2023-01-02                     NaN                     NaN
# 2023-01-16                     NaN                     NaN
#
#             Close: 60 days rolling  EWM_0.1  EWM_0.3  EWMA_5days  \
# Date
# 2017-01-18                     NaN     62.5     62.5        62.5
# 2017-02-20                     NaN      NaN      NaN         NaN
# 2017-04-14                     NaN      NaN      NaN         NaN
# 2017-05-29                     NaN      NaN      NaN         NaN
# 2017-07-04                     NaN      NaN      NaN         NaN
# 2017-09-04                     NaN      NaN      NaN         NaN
# 2017-11-23                     NaN      NaN      NaN         NaN
# 2017-12-25                     NaN      NaN      NaN         NaN
# 2018-01-01                     NaN      NaN      NaN         NaN
# 2018-01-15                     NaN      NaN      NaN         NaN
# 2018-02-19                     NaN      NaN      NaN         NaN
# 2018-03-30                     NaN      NaN      NaN         NaN
# 2018-05-28                     NaN      NaN      NaN         NaN
# 2018-07-04                     NaN      NaN      NaN         NaN
# 2018-09-03                     NaN      NaN      NaN         NaN
# 2018-11-22                     NaN      NaN      NaN         NaN
# 2018-12-05                     NaN      NaN      NaN         NaN
# 2018-12-25                     NaN      NaN      NaN         NaN
# 2019-01-01                     NaN      NaN      NaN         NaN
# 2019-01-21                     NaN      NaN      NaN         NaN
# 2019-02-18                     NaN      NaN      NaN         NaN
# 2019-04-19                     NaN      NaN      NaN         NaN
# 2019-05-27                     NaN      NaN      NaN         NaN
# 2019-07-04                     NaN      NaN      NaN         NaN
# 2019-09-02                     NaN      NaN      NaN         NaN
# 2019-11-28                     NaN      NaN      NaN         NaN
# 2019-12-25                     NaN      NaN      NaN         NaN
# 2020-01-01                     NaN      NaN      NaN         NaN
# 2020-01-20                     NaN      NaN      NaN         NaN
# 2020-02-17                     NaN      NaN      NaN         NaN
# 2020-04-10                     NaN      NaN      NaN         NaN
# 2020-05-25                     NaN      NaN      NaN         NaN
# 2020-07-03                     NaN      NaN      NaN         NaN
# 2020-09-07                     NaN      NaN      NaN         NaN
# 2020-11-26                     NaN      NaN      NaN         NaN
# 2020-12-25                     NaN      NaN      NaN         NaN
# 2021-01-01                     NaN      NaN      NaN         NaN
# 2021-01-18                     NaN      NaN      NaN         NaN
# 2021-02-15                     NaN      NaN      NaN         NaN
# 2021-04-02                     NaN      NaN      NaN         NaN
# 2021-05-31                     NaN      NaN      NaN         NaN
# 2021-07-05                     NaN      NaN      NaN         NaN
# 2021-09-06                     NaN      NaN      NaN         NaN
# 2021-11-25                     NaN      NaN      NaN         NaN
# 2021-12-24                     NaN      NaN      NaN         NaN
# 2022-01-17                     NaN      NaN      NaN         NaN
# 2022-02-21                     NaN      NaN      NaN         NaN
# 2022-04-15                     NaN      NaN      NaN         NaN
# 2022-05-30                     NaN      NaN      NaN         NaN
# 2022-06-20                     NaN      NaN      NaN         NaN
# 2022-07-04                     NaN      NaN      NaN         NaN
# 2022-09-05                     NaN      NaN      NaN         NaN
# 2022-11-24                     NaN      NaN      NaN         NaN
# 2022-12-26                     NaN      NaN      NaN         NaN
# 2023-01-02                     NaN      NaN      NaN         NaN
# 2023-01-16                     NaN      NaN      NaN         NaN
#
#             Close - First order difference
# Date
# 2017-01-18                             NaN
# 2017-02-20                             NaN
# 2017-04-14                             NaN
# 2017-05-29                             NaN
# 2017-07-04                             NaN
# 2017-09-04                             NaN
# 2017-11-23                             NaN
# 2017-12-25                             NaN
# 2018-01-01                             NaN
# 2018-01-15                             NaN
# 2018-02-19                             NaN
# 2018-03-30                             NaN
# 2018-05-28                             NaN
# 2018-07-04                             NaN
# 2018-09-03                             NaN
# 2018-11-22                             NaN
# 2018-12-05                             NaN
# 2018-12-25                             NaN
# 2019-01-01                             NaN
# 2019-01-21                             NaN
# 2019-02-18                             NaN
# 2019-04-19                             NaN
# 2019-05-27                             NaN
# 2019-07-04                             NaN
# 2019-09-02                             NaN
# 2019-11-28                             NaN
# 2019-12-25                             NaN
# 2020-01-01                             NaN
# 2020-01-20                             NaN
# 2020-02-17                             NaN
# 2020-04-10                             NaN
# 2020-05-25                             NaN
# 2020-07-03                             NaN
# 2020-09-07                             NaN
# 2020-11-26                             NaN
# 2020-12-25                             NaN
# 2021-01-01                             NaN
# 2021-01-18                             NaN
# 2021-02-15                             NaN
# 2021-04-02                             NaN
# 2021-05-31                             NaN
# 2021-07-05                             NaN
# 2021-09-06                             NaN
# 2021-11-25                             NaN
# 2021-12-24                             NaN
# 2022-01-17                             NaN
# 2022-02-21                             NaN
# 2022-04-15                             NaN
# 2022-05-30                             NaN
# 2022-06-20                             NaN
# 2022-07-04                             NaN
# 2022-09-05                             NaN
# 2022-11-24                             NaN
# 2022-12-26                             NaN
# 2023-01-02                             NaN
# 2023-01-16                             NaN

# %% [markdown]
# #### Now let's fill these missing NaN values using fillna() function. But we're not gonna replace the missing values of the very first row because those NaN values were formed as a result of smoothing process.

# %%
df_new.fillna(method='pad', inplace=True, axis=0) 
# pad method propagates the last valid observation to the missing value rowwise

# %%
df_new[df_new.isna().any(1)]
# since the pad method donot find any values before the very first NaN values, it left the NaN values as it is
# Out:
#                  Open       High        Low  Close  Adj Close      Volume  \
# Date
# 2017-01-18  62.669998  62.700001  62.119999   62.5  57.571678  19670100.0
#
#             Close: 15 days rolling  Close: 30 days rolling  \
# Date
# 2017-01-18                     NaN                     NaN
#
#             Close: 60 days rolling  EWM_0.1  EWM_0.3  EWMA_5days  \
# Date
# 2017-01-18                     NaN     62.5     62.5        62.5
#
#             Close - First order difference
# Date
# 2017-01-18                             NaN

# %%
df_new.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Close: 15 days rolling', 'Close: 30 days rolling',
#        'Close: 60 days rolling', 'EWM_0.1', 'EWM_0.3', 'EWMA_5days',
#        'Close - First order difference'],
#       dtype='object')

# %%
# df_new.drop(['Open: 15 days rolling', 'Open: 30 days rolling', 
#             'Open: 60 days rolling', 'EWM_0.1', 'EWM_0.3', 'EWMA_5days'], inplace=True, axis=1)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

#since the magnitude of seasonal values in our dataset is independent of trend we'll use additive decomposition
decomposition_result = seasonal_decompose(x=df_new['Close'], model='additive')
fig, ax = plt.subplots(4,1, sharex=True)
fig.set_figheight(15)
fig.set_figwidth(10)

ax[0].plot(df_new['Close'])
ax[0].title.set_text('Original data')

ax[1].plot(decomposition_result.trend)
ax[1].title.set_text('Trend')

ax[2].plot(decomposition_result.seasonal)
ax[2].title.set_text('Seasonality')

ax[3].plot(decomposition_result.resid)
ax[3].title.set_text('Residual obtained after removing trend and seasonality')

# %%
df_new[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']].plot(figsize=(12,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
adf_test(decomposition_result.resid.fillna(0))
# Out:
# Reject null hypothesis! Indicates that the data is stationary.
# ADF statistic          -1.389318e+01
# p-value                 5.916518e-26
# Used lags               2.200000e+01
# Observations used       1.542000e+03
# Critical value (1%)    -3.434598e+00
# Critical value (5%)    -2.863416e+00
# Critical value (10%)   -2.567769e+00
# dtype: float64

# %%
adf_test(decomposition_result.resid.dropna())
# Out:
# Reject null hypothesis! Indicates that the data is stationary.
# ADF statistic          -1.386230e+01
# p-value                 6.694628e-26
# Used lags               2.200000e+01
# Observations used       1.538000e+03
# Critical value (1%)    -3.434609e+00
# Critical value (5%)    -2.863421e+00
# Critical value (10%)   -2.567771e+00
# dtype: float64

# %%
plot_acf(decomposition_result.resid);
plot_pacf(decomposition_result.resid);

# %% [markdown]
# ## LSTM - DeepLearning

# %%
data = df['Close']
data = data.reset_index()
data.drop('Date', axis=1, inplace=True)
data.head()
# Out:
#        Close
# 0  62.500000
# 1  62.299999
# 2  62.740002
# 3  62.959999
# 4  63.520000

# %%
# Scale data
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(np.array(data))

# %%
scaled_data.shape
# Out:
# (1510, 1)

# %%
train_size = int(len(data)*0.70)
test_size = len(data) - train_size

train_set, test_set = scaled_data[0:train_size, :], scaled_data[train_size:scaled_data.shape[0], :]

# %%
train_set.shape, test_set.shape
# Out:
# ((1057, 1), (453, 1))

# %%
type(train_set)
# Out:
# numpy.ndarray

# %%
# def  get_train_test_data(dataset, timestamp=1):
#     data_X = []
#     data_y = []
#     for i in range(timestamp, len(dataset)):
#         data_X.append(train_set[i-timestamp:i, 0])
#         data_y.append(train_set[i, 0])
#     return np.array(data_X), np.array(data_y)

# %%
def get_train_test_data(dataset, timestamp=1):
    dataX = []
    dataY = []
    for i in range(len(dataset)-timestamp-1):
        a = dataset[i:(i+timestamp), 0] 
        dataX.append(a)
        dataY.append(dataset[i + timestamp, 0])
    return np.array(dataX), np.array(dataY)

# %%
trainx , trainy = get_train_test_data(train_set, timestamp=60)

# %%
trainx.shape, trainy.shape
# Out:
# ((996, 60), (996,))

# %%
testx, testy = get_train_test_data(test_set, timestamp=60)

# %%
testx.shape, testy.shape
# Out:
# ((392, 60), (392,))

# %%
# reshape the data to [sample_size, time_step, features], here we're working with only 1 feature i.e. Close
train_X = trainx.reshape(trainx.shape[0], trainx.shape[1], 1)
test_X = testx.reshape(testx.shape[0], testx.shape[1], 1)

# %%
train_X.shape, test_X.shape
# Out:
# ((996, 60, 1), (392, 60, 1))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# Build LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (train_X.shape[1],1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# %%
# Compile the model
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 60, 50)            10400
#
#  lstm_3 (LSTM)               (None, 50)                20200
#
#  dense_2 (Dense)             (None, 25)                1275
#
#  dense_3 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 31,901
# Trainable params: 31,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
# stop the training when there is no improvement in the loss for 100 consecutive epoch
# and save the best model observed during training for later use

callbacks = [EarlyStopping(monitor='val_loss', mode='min', patience=10, verbose=1),
            ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)]
                         
# fit the model
history = model.fit(train_X, trainy, epochs=100, batch_size=32, 
                    callbacks=callbacks, validation_data=(test_X, testy))
# Out:
# Epoch 1/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0129
# Epoch 1: val_loss improved from inf to 0.00331, saving model to best_model.h5
# 32/32 [==============================] - 4s 51ms/step - loss: 0.0129 - val_loss: 0.0033
# Epoch 2/100
# 32/32 [==============================] - ETA: 0s - loss: 5.0532e-04
# Epoch 2: val_loss improved from 0.00331 to 0.00174, saving model to best_model.h5
# 32/32 [==============================] - 1s 28ms/step - loss: 5.0532e-04 - val_loss: 0.0017
# Epoch 3/100
# 31/32 [============================>.] - ETA: 0s - loss: 3.7749e-04
# Epoch 3: val_loss did not improve from 0.00174
# 32/32 [==============================] - 1s 27ms/step - loss: 3.7679e-04 - val_loss: 0.0025
# Epoch 4/100
# 32/32 [==============================] - ETA: 0s - loss: 3.4510e-04
# Epoch 4: val_loss did not improve from 0.00174
# 32/32 [==============================] - 1s 27ms/step - loss: 3.4510e-04 - val_loss: 0.0018
# Epoch 5/100
# 31/32 [============================>.] - ETA: 0s - loss: 3.3584e-04
# Epoch 5: val_loss did not improve from 0.00174
# 32/32 [==============================] - 1s 27ms/step - loss: 3.3473e-04 - val_loss: 0.0018
# Epoch 6/100
# 30/32 [===========================>..] - ETA: 0s - loss: 3.3345e-04
# Epoch 6: val_loss improved from 0.00174 to 0.00172, saving model to best_model.h5
# 32/32 [==============================] - 1s 28ms/step - loss: 3.2643e-04 - val_loss: 0.0017
# Epoch 7/100
# 32/32 [==============================] - ETA: 0s - loss: 3.2841e-04
# Epoch 7: val_loss improved from 0.00172 to 0.00153, saving model to best_model.h5
# 32/32 [==============================] - 1s 28ms/step - loss: 3.2841e-04 - val_loss: 0.0015
# Epoch 8/100
# 31/32 [============================>.] - ETA: 0s - loss: 3.2648e-04
# Epoch 8: val_loss improved from 0.00153 to 0.00151, saving model to best_model.h5
# 32/32 [==============================] - 1s 28ms/step - loss: 3.2543e-04 - val_loss: 0.0015
# Epoch 9/100
# 32/32 [==============================] - ETA: 0s - loss: 3.0714e-04
# Epoch 9: val_loss did not improve from 0.00151
# 32/32 [==============================] - 1s 27ms/step - loss: 3.0714e-04 - val_loss: 0.0016
# Epoch 10/100
# 31/32 [============================>.] - ETA: 0s - loss: 3.2388e-04
# Epoch 10: val_loss improved from 0.00151 to 0.00144, saving model to best_model.h5
# 32/32 [==============================] - 1s 29ms/step - loss: 3.2282e-04 - val_loss: 0.0014
# Epoch 11/100
# 30/32 [===========================>..] - ETA: 0s - loss: 2.9601e-04
# Epoch 11: val_loss did not improve from 0.00144
# 32/32 [==============================] - 1s 27ms/step - loss: 2.9245e-04 - val_loss: 0.0015
# Epoch 12/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.8826e-04
# Epoch 12: val_loss did not improve from 0.00144
# 32/32 [==============================] - 1s 28ms/step - loss: 2.8757e-04 - val_loss: 0.0015
# Epoch 13/100
# 32/32 [==============================] - ETA: 0s - loss: 2.8672e-04
# Epoch 13: val_loss did not improve from 0.00144
# 32/32 [==============================] - 1s 27ms/step - loss: 2.8672e-04 - val_loss: 0.0015
# Epoch 14/100
# 32/32 [==============================] - ETA: 0s - loss: 2.9045e-04
# Epoch 14: val_loss improved from 0.00144 to 0.00135, saving model to best_model.h5
# 32/32 [==============================] - 1s 28ms/step - loss: 2.9045e-04 - val_loss: 0.0013
# Epoch 15/100
# 32/32 [==============================] - ETA: 0s - loss: 2.8987e-04
# Epoch 15: val_loss improved from 0.00135 to 0.00132, saving model to best_model.h5
# 32/32 [==============================] - 1s 28ms/step - loss: 2.8987e-04 - val_loss: 0.0013
# Epoch 16/100
# 32/32 [==============================] - ETA: 0s - loss: 2.8109e-04
# Epoch 16: val_loss improved from 0.00132 to 0.00127, saving model to best_model.h5
# 32/32 [==============================] - 1s 28ms/step - loss: 2.8109e-04 - val_loss: 0.0013
# Epoch 17/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.7604e-04
# Epoch 17: val_loss did not improve from 0.00127
# 32/32 [==============================] - 1s 28ms/step - loss: 2.7511e-04 - val_loss: 0.0016
# Epoch 18/100
# 32/32 [==============================] - ETA: 0s - loss: 2.5778e-04
# Epoch 18: val_loss improved from 0.00127 to 0.00122, saving model to best_model.h5
# 32/32 [==============================] - 1s 28ms/step - loss: 2.5778e-04 - val_loss: 0.0012
# Epoch 19/100
# 30/32 [===========================>..] - ETA: 0s - loss: 3.1157e-04
# Epoch 19: val_loss did not improve from 0.00122
# 32/32 [==============================] - 1s 27ms/step - loss: 3.0789e-04 - val_loss: 0.0013
# Epoch 20/100
# 32/32 [==============================] - ETA: 0s - loss: 2.7877e-04
# Epoch 20: val_loss improved from 0.00122 to 0.00113, saving model to best_model.h5
# 32/32 [==============================] - 1s 28ms/step - loss: 2.7877e-04 - val_loss: 0.0011
# Epoch 21/100
# 30/32 [===========================>..] - ETA: 0s - loss: 2.4864e-04
# Epoch 21: val_loss improved from 0.00113 to 0.00113, saving model to best_model.h5
# 32/32 [==============================] - 1s 28ms/step - loss: 2.5080e-04 - val_loss: 0.0011
# Epoch 22/100
# 32/32 [==============================] - ETA: 0s - loss: 2.7275e-04
# Epoch 22: val_loss did not improve from 0.00113
# 32/32 [==============================] - 1s 27ms/step - loss: 2.7275e-04 - val_loss: 0.0015
# Epoch 23/100
# 30/32 [===========================>..] - ETA: 0s - loss: 2.3062e-04
# Epoch 23: val_loss did not improve from 0.00113
# 32/32 [==============================] - 1s 30ms/step - loss: 2.3796e-04 - val_loss: 0.0017
# Epoch 24/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.3469e-04
# Epoch 24: val_loss improved from 0.00113 to 0.00113, saving model to best_model.h5
# 32/32 [==============================] - 1s 32ms/step - loss: 2.3489e-04 - val_loss: 0.0011
# Epoch 25/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.1557e-04
# Epoch 25: val_loss improved from 0.00113 to 0.00107, saving model to best_model.h5
# 32/32 [==============================] - 1s 31ms/step - loss: 2.1479e-04 - val_loss: 0.0011
# Epoch 26/100
# 30/32 [===========================>..] - ETA: 0s - loss: 2.2275e-04
# Epoch 26: val_loss did not improve from 0.00107
# 32/32 [==============================] - 1s 30ms/step - loss: 2.1905e-04 - val_loss: 0.0020
# Epoch 27/100
# 32/32 [==============================] - ETA: 0s - loss: 2.4318e-04
# Epoch 27: val_loss improved from 0.00107 to 0.00096, saving model to best_model.h5
# 32/32 [==============================] - 1s 29ms/step - loss: 2.4318e-04 - val_loss: 9.5669e-04
# Epoch 28/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.3905e-04
# Epoch 28: val_loss did not improve from 0.00096
# 32/32 [==============================] - 1s 29ms/step - loss: 2.4068e-04 - val_loss: 0.0021
# Epoch 29/100
# 32/32 [==============================] - ETA: 0s - loss: 3.1859e-04
# Epoch 29: val_loss improved from 0.00096 to 0.00088, saving model to best_model.h5
# 32/32 [==============================] - 1s 29ms/step - loss: 3.1859e-04 - val_loss: 8.8406e-04
# Epoch 30/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.3472e-04
# Epoch 30: val_loss did not improve from 0.00088
# 32/32 [==============================] - 1s 31ms/step - loss: 2.3433e-04 - val_loss: 0.0010
# Epoch 31/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.1222e-04
# Epoch 31: val_loss did not improve from 0.00088
# 32/32 [==============================] - 1s 30ms/step - loss: 2.1174e-04 - val_loss: 0.0011
# Epoch 32/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.8908e-04
# Epoch 32: val_loss improved from 0.00088 to 0.00086, saving model to best_model.h5
# 32/32 [==============================] - 1s 32ms/step - loss: 1.8875e-04 - val_loss: 8.5506e-04
# Epoch 33/100
# 32/32 [==============================] - ETA: 0s - loss: 2.2743e-04
# Epoch 33: val_loss did not improve from 0.00086
# 32/32 [==============================] - 1s 28ms/step - loss: 2.2743e-04 - val_loss: 0.0011
# Epoch 34/100
# 32/32 [==============================] - ETA: 0s - loss: 1.9323e-04
# Epoch 34: val_loss improved from 0.00086 to 0.00083, saving model to best_model.h5
# 32/32 [==============================] - 1s 29ms/step - loss: 1.9323e-04 - val_loss: 8.2899e-04
# Epoch 35/100
# 32/32 [==============================] - ETA: 0s - loss: 1.9594e-04
# Epoch 35: val_loss did not improve from 0.00083
# 32/32 [==============================] - 1s 28ms/step - loss: 1.9594e-04 - val_loss: 0.0019
# Epoch 36/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.8521e-04
# Epoch 36: val_loss did not improve from 0.00083
# 32/32 [==============================] - 1s 29ms/step - loss: 1.8471e-04 - val_loss: 0.0011
# Epoch 37/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.0932e-04
# Epoch 37: val_loss improved from 0.00083 to 0.00078, saving model to best_model.h5
# 32/32 [==============================] - 1s 31ms/step - loss: 2.1157e-04 - val_loss: 7.7857e-04
# Epoch 38/100
# 32/32 [==============================] - ETA: 0s - loss: 2.1977e-04
# Epoch 38: val_loss did not improve from 0.00078
# 32/32 [==============================] - 1s 28ms/step - loss: 2.1977e-04 - val_loss: 9.1485e-04
# Epoch 39/100
# 32/32 [==============================] - ETA: 0s - loss: 2.1395e-04
# Epoch 39: val_loss did not improve from 0.00078
# 32/32 [==============================] - 1s 28ms/step - loss: 2.1395e-04 - val_loss: 0.0013
# Epoch 40/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.8309e-04
# Epoch 40: val_loss improved from 0.00078 to 0.00076, saving model to best_model.h5
# 32/32 [==============================] - 1s 29ms/step - loss: 1.8201e-04 - val_loss: 7.5605e-04
# Epoch 41/100
# 32/32 [==============================] - ETA: 0s - loss: 1.7520e-04
# Epoch 41: val_loss did not improve from 0.00076
# 32/32 [==============================] - 1s 28ms/step - loss: 1.7520e-04 - val_loss: 7.7289e-04
# Epoch 42/100
# 32/32 [==============================] - ETA: 0s - loss: 1.8044e-04
# Epoch 42: val_loss improved from 0.00076 to 0.00074, saving model to best_model.h5
# 32/32 [==============================] - 1s 28ms/step - loss: 1.8044e-04 - val_loss: 7.3918e-04
# Epoch 43/100
# 32/32 [==============================] - ETA: 0s - loss: 1.6879e-04
# Epoch 43: val_loss did not improve from 0.00074
# 32/32 [==============================] - 1s 28ms/step - loss: 1.6879e-04 - val_loss: 8.2736e-04
# Epoch 44/100
# 32/32 [==============================] - ETA: 0s - loss: 1.8668e-04
# Epoch 44: val_loss did not improve from 0.00074
# 32/32 [==============================] - 1s 28ms/step - loss: 1.8668e-04 - val_loss: 9.6173e-04
# Epoch 45/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.7659e-04
# Epoch 45: val_loss did not improve from 0.00074
# 32/32 [==============================] - 1s 28ms/step - loss: 1.7631e-04 - val_loss: 9.8211e-04
# Epoch 46/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.9047e-04
# Epoch 46: val_loss improved from 0.00074 to 0.00072, saving model to best_model.h5
# 32/32 [==============================] - 1s 28ms/step - loss: 1.8809e-04 - val_loss: 7.1644e-04
# Epoch 47/100
# 32/32 [==============================] - ETA: 0s - loss: 1.6537e-04
# Epoch 47: val_loss did not improve from 0.00072
# 32/32 [==============================] - 1s 28ms/step - loss: 1.6537e-04 - val_loss: 8.7535e-04
# Epoch 48/100
# 32/32 [==============================] - ETA: 0s - loss: 1.6790e-04
# Epoch 48: val_loss did not improve from 0.00072
# 32/32 [==============================] - 1s 28ms/step - loss: 1.6790e-04 - val_loss: 8.0671e-04
# Epoch 49/100
# 32/32 [==============================] - ETA: 0s - loss: 1.6027e-04
# Epoch 49: val_loss did not improve from 0.00072
# 32/32 [==============================] - 1s 28ms/step - loss: 1.6027e-04 - val_loss: 7.9278e-04
# Epoch 50/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.5112e-04
# Epoch 50: val_loss did not improve from 0.00072
# 32/32 [==============================] - 1s 29ms/step - loss: 1.5187e-04 - val_loss: 0.0012
# Epoch 51/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.6674e-04
# Epoch 51: val_loss did not improve from 0.00072
# 32/32 [==============================] - 1s 30ms/step - loss: 1.6727e-04 - val_loss: 7.3037e-04
# Epoch 52/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.7455e-04
# Epoch 52: val_loss improved from 0.00072 to 0.00072, saving model to best_model.h5
# 32/32 [==============================] - 1s 28ms/step - loss: 1.7315e-04 - val_loss: 7.1536e-04
# Epoch 53/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.7504e-04
# Epoch 53: val_loss did not improve from 0.00072
# 32/32 [==============================] - 1s 28ms/step - loss: 1.7359e-04 - val_loss: 8.2429e-04
# Epoch 54/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.5397e-04
# Epoch 54: val_loss improved from 0.00072 to 0.00068, saving model to best_model.h5
# 32/32 [==============================] - 1s 30ms/step - loss: 1.5344e-04 - val_loss: 6.7592e-04
# Epoch 55/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.4692e-04
# Epoch 55: val_loss did not improve from 0.00068
# 32/32 [==============================] - 1s 30ms/step - loss: 1.4659e-04 - val_loss: 7.4256e-04
# Epoch 56/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.5714e-04
# Epoch 56: val_loss improved from 0.00068 to 0.00065, saving model to best_model.h5
# 32/32 [==============================] - 1s 30ms/step - loss: 1.5709e-04 - val_loss: 6.5232e-04
# Epoch 57/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.5365e-04
# Epoch 57: val_loss did not improve from 0.00065
# 32/32 [==============================] - 1s 29ms/step - loss: 1.5341e-04 - val_loss: 0.0011
# Epoch 58/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.5041e-04
# Epoch 58: val_loss did not improve from 0.00065
# 32/32 [==============================] - 1s 28ms/step - loss: 1.4923e-04 - val_loss: 6.6732e-04
# Epoch 59/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.6359e-04
# Epoch 59: val_loss did not improve from 0.00065
# 32/32 [==============================] - 1s 28ms/step - loss: 1.6309e-04 - val_loss: 9.0943e-04
# Epoch 60/100
# 32/32 [==============================] - ETA: 0s - loss: 1.4539e-04
# Epoch 60: val_loss did not improve from 0.00065
# 32/32 [==============================] - 1s 28ms/step - loss: 1.4539e-04 - val_loss: 0.0011
# Epoch 61/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.6483e-04
# Epoch 61: val_loss did not improve from 0.00065
# 32/32 [==============================] - 1s 28ms/step - loss: 1.6425e-04 - val_loss: 6.6548e-04
# Epoch 62/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.5615e-04
# Epoch 62: val_loss did not improve from 0.00065
# 32/32 [==============================] - 1s 29ms/step - loss: 1.5661e-04 - val_loss: 0.0013
# Epoch 63/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.5852e-04
# Epoch 63: val_loss improved from 0.00065 to 0.00063, saving model to best_model.h5
# 32/32 [==============================] - 1s 32ms/step - loss: 1.5839e-04 - val_loss: 6.3106e-04
# Epoch 64/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.5169e-04
# Epoch 64: val_loss did not improve from 0.00063
# 32/32 [==============================] - 1s 30ms/step - loss: 1.5163e-04 - val_loss: 7.0900e-04
# Epoch 65/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.7667e-04
# Epoch 65: val_loss improved from 0.00063 to 0.00062, saving model to best_model.h5
# 32/32 [==============================] - 1s 31ms/step - loss: 1.7662e-04 - val_loss: 6.2259e-04
# Epoch 66/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.6110e-04
# Epoch 66: val_loss did not improve from 0.00062
# 32/32 [==============================] - 1s 31ms/step - loss: 1.6320e-04 - val_loss: 6.5390e-04
# Epoch 67/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.8552e-04
# Epoch 67: val_loss did not improve from 0.00062
# 32/32 [==============================] - 1s 31ms/step - loss: 1.8691e-04 - val_loss: 0.0011
# Epoch 68/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.3745e-04
# Epoch 68: val_loss did not improve from 0.00062
# 32/32 [==============================] - 1s 33ms/step - loss: 1.3733e-04 - val_loss: 0.0012
# Epoch 69/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.3812e-04
# Epoch 69: val_loss did not improve from 0.00062
# 32/32 [==============================] - 1s 31ms/step - loss: 1.3819e-04 - val_loss: 7.2901e-04
# Epoch 70/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.4877e-04
# Epoch 70: val_loss improved from 0.00062 to 0.00058, saving model to best_model.h5
# 32/32 [==============================] - 1s 31ms/step - loss: 1.4832e-04 - val_loss: 5.8497e-04
# Epoch 71/100
# 32/32 [==============================] - ETA: 0s - loss: 1.4225e-04
# Epoch 71: val_loss did not improve from 0.00058
# 32/32 [==============================] - 1s 28ms/step - loss: 1.4225e-04 - val_loss: 6.8593e-04
# Epoch 72/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.5690e-04
# Epoch 72: val_loss improved from 0.00058 to 0.00056, saving model to best_model.h5
# 32/32 [==============================] - 1s 29ms/step - loss: 1.5366e-04 - val_loss: 5.6307e-04
# Epoch 73/100
# 32/32 [==============================] - ETA: 0s - loss: 1.3496e-04
# Epoch 73: val_loss did not improve from 0.00056
# 32/32 [==============================] - 1s 28ms/step - loss: 1.3496e-04 - val_loss: 0.0010
# Epoch 74/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.3096e-04
# Epoch 74: val_loss did not improve from 0.00056
# 32/32 [==============================] - 1s 28ms/step - loss: 1.3473e-04 - val_loss: 0.0012
# Epoch 75/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.7319e-04
# Epoch 75: val_loss did not improve from 0.00056
# 32/32 [==============================] - 1s 29ms/step - loss: 1.7056e-04 - val_loss: 6.0225e-04
# Epoch 76/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.4197e-04
# Epoch 76: val_loss did not improve from 0.00056
# 32/32 [==============================] - 1s 28ms/step - loss: 1.4181e-04 - val_loss: 0.0016
# Epoch 77/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.8005e-04
# Epoch 77: val_loss did not improve from 0.00056
# 32/32 [==============================] - 1s 30ms/step - loss: 1.7802e-04 - val_loss: 0.0011
# Epoch 78/100
# 32/32 [==============================] - ETA: 0s - loss: 1.4822e-04
# Epoch 78: val_loss did not improve from 0.00056
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4822e-04 - val_loss: 8.1403e-04
# Epoch 79/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.4426e-04
# Epoch 79: val_loss did not improve from 0.00056
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4489e-04 - val_loss: 5.8568e-04
# Epoch 80/100
# 32/32 [==============================] - ETA: 0s - loss: 1.4429e-04
# Epoch 80: val_loss improved from 0.00056 to 0.00053, saving model to best_model.h5
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4429e-04 - val_loss: 5.3370e-04
# Epoch 81/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.2955e-04
# Epoch 81: val_loss did not improve from 0.00053
# 32/32 [==============================] - 1s 29ms/step - loss: 1.2846e-04 - val_loss: 8.5414e-04
# Epoch 82/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.2645e-04
# Epoch 82: val_loss did not improve from 0.00053
# 32/32 [==============================] - 1s 28ms/step - loss: 1.3108e-04 - val_loss: 8.6130e-04
# Epoch 83/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.2397e-04
# Epoch 83: val_loss did not improve from 0.00053
# 32/32 [==============================] - 1s 28ms/step - loss: 1.2228e-04 - val_loss: 6.1546e-04
# Epoch 84/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.2495e-04
# Epoch 84: val_loss did not improve from 0.00053
# 32/32 [==============================] - 1s 29ms/step - loss: 1.2545e-04 - val_loss: 6.8883e-04
# Epoch 85/100
# 32/32 [==============================] - ETA: 0s - loss: 1.3465e-04
# Epoch 85: val_loss did not improve from 0.00053
# 32/32 [==============================] - 1s 28ms/step - loss: 1.3465e-04 - val_loss: 7.5397e-04
# Epoch 86/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.1767e-04
# Epoch 86: val_loss did not improve from 0.00053
# 32/32 [==============================] - 1s 29ms/step - loss: 1.1749e-04 - val_loss: 8.1117e-04
# Epoch 87/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.4121e-04
# Epoch 87: val_loss did not improve from 0.00053
# 32/32 [==============================] - 1s 30ms/step - loss: 1.4053e-04 - val_loss: 7.4302e-04
# Epoch 88/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.3196e-04
# Epoch 88: val_loss did not improve from 0.00053
# 32/32 [==============================] - 1s 28ms/step - loss: 1.3153e-04 - val_loss: 5.5348e-04
# Epoch 89/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.1572e-04
# Epoch 89: val_loss improved from 0.00053 to 0.00051, saving model to best_model.h5
# 32/32 [==============================] - 1s 29ms/step - loss: 1.1459e-04 - val_loss: 5.0697e-04
# Epoch 90/100
# 32/32 [==============================] - ETA: 0s - loss: 1.2711e-04
# Epoch 90: val_loss did not improve from 0.00051
# 32/32 [==============================] - 1s 29ms/step - loss: 1.2711e-04 - val_loss: 6.4987e-04
# Epoch 91/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.1132e-04
# Epoch 91: val_loss did not improve from 0.00051
# 32/32 [==============================] - 1s 29ms/step - loss: 1.1184e-04 - val_loss: 5.8854e-04
# Epoch 92/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.4033e-04
# Epoch 92: val_loss did not improve from 0.00051
# 32/32 [==============================] - 1s 28ms/step - loss: 1.3994e-04 - val_loss: 9.1852e-04
# Epoch 93/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.4685e-04
# Epoch 93: val_loss did not improve from 0.00051
# 32/32 [==============================] - 1s 28ms/step - loss: 1.4698e-04 - val_loss: 5.7632e-04
# Epoch 94/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.3379e-04
# Epoch 94: val_loss improved from 0.00051 to 0.00050, saving model to best_model.h5
# 32/32 [==============================] - 1s 30ms/step - loss: 1.3344e-04 - val_loss: 4.9908e-04
# Epoch 95/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.2877e-04
# Epoch 95: val_loss did not improve from 0.00050
# 32/32 [==============================] - 1s 30ms/step - loss: 1.3148e-04 - val_loss: 5.5114e-04
# Epoch 96/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.2548e-04
# Epoch 96: val_loss did not improve from 0.00050
# 32/32 [==============================] - 1s 34ms/step - loss: 1.2512e-04 - val_loss: 6.3367e-04
# Epoch 97/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.1533e-04
# Epoch 97: val_loss did not improve from 0.00050
# 32/32 [==============================] - 1s 31ms/step - loss: 1.1497e-04 - val_loss: 5.0435e-04
# Epoch 98/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.1060e-04
# Epoch 98: val_loss did not improve from 0.00050
# 32/32 [==============================] - 1s 30ms/step - loss: 1.1038e-04 - val_loss: 5.5879e-04
# Epoch 99/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.3682e-04
# Epoch 99: val_loss did not improve from 0.00050
# 32/32 [==============================] - 1s 30ms/step - loss: 1.3643e-04 - val_loss: 5.1042e-04
# Epoch 100/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.1982e-04
# Epoch 100: val_loss did not improve from 0.00050
# 32/32 [==============================] - 1s 30ms/step - loss: 1.1945e-04 - val_loss: 6.1880e-04

# %%
from tensorflow.keras.models import load_model
model = load_model('best_model.h5')

# %%
7.0913e-04 - 6.8272e-04

# %%
6.8272e-04 - 5.5766e-04

# %%
6.8272e-04

# %%
# get predictions for test set
test_predict = model.predict(test_X)
# transform the values to contain the same values range as testy data contains
test_predict_transformed = scaler.inverse_transform(test_predict)
# get predictions for train set
train_predict = model.predict(train_X)
train_predict_transformed = scaler.inverse_transform(train_predict)
# Out:
# 13/13 [==============================] - 1s 8ms/step
# 32/32 [==============================] - 0s 8ms/step

# %%
from sklearn.metrics import mean_squared_error

# %%
print('Train MSE:', np.sqrt(mean_squared_error(trainy, train_predict_transformed)))
print('Test MSE:', np.sqrt(mean_squared_error(testy,  test_predict_transformed)))
# Out:
# Train MSE: 145.25782745811284
# Test MSE: 281.2778361907668

# %%
len(train_set), len(train_X), len(trainy), len(train_predict_transformed)
# Out:
# (1057, 996, 996, 996)

# %%
len(test_set), len(test_X), len(testy), len(test_predict_transformed)
# Out:
# (453, 392, 392, 392)

# %%
plt.plot(scaler.inverse_transform(trainx))
plt.plot(train_predict_transformed);

# %%
plt.plot(scaler.inverse_transform(testx))
plt.plot(test_predict_transformed);

# %%
### Plotting 
# shift train predictions for plotting
look_back=60
trainPredictPlot = np.empty_like(scaled_data)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict_transformed)+look_back, :] = train_predict_transformed

# shift test predictions for plotting
testPredictPlot = np.empty_like(scaled_data)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict_transformed)+(look_back*2)+1:len(scaled_data)-1, :] = test_predict_transformed

# plot baseline and predictions
plt.figure(figsize=(12,6))
plt.plot(scaler.inverse_transform(scaled_data), linewidth=1.7, label='Original data')
plt.plot(trainPredictPlot, linewidth=1.7, label='Prediction made on train data')
plt.plot(testPredictPlot, linewidth=1.7, label='Prediction made on test data')
plt.title('Microsoft Stock Price Prediction')
plt.xlabel('Datetime')
plt.ylabel('Stock Price in USD ($)')
plt.legend()
plt.show()

# %%
len(df.index)
# Out:
# 1510

# %%
### Plotting 
# shift train predictions for plotting
look_back=60
trainPredictPlot = np.empty_like(scaled_data)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict_transformed)+look_back, :] = train_predict_transformed

# shift test predictions for plotting
testPredictPlot = np.empty_like(scaled_data)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict_transformed)+(look_back*2)+1:len(scaled_data)-1, :] = test_predict_transformed

# plot baseline and predictions
plt.figure(figsize=(12,6))

plt.plot(scaler.inverse_transform(scaled_data), linewidth=1.7, label='Original data')
plt.plot(trainPredictPlot, linewidth=1.7, xlim=['2020-12-01', '2023-01-01'], label='Prediction made on train data')
plt.plot(testPredictPlot, linewidth=1.7, xlim=['2020-12-01', '2023-01-01'], label='Prediction made on test data')

plt.title('Microsoft Stock Price Prediction')
plt.xlabel('Datetime')
plt.ylabel('Stock Price in USD ($)')
# plt.xticks(range(0,200))
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [117], in <cell line: 17>()
#      14 plt.figure(figsize=(12,6))
#      16 plt.plot(scaler.inverse_transform(scaled_data), linewidth=1.7, label='Original data')
# ---> 17 plt.plot(trainPredictPlot, linewidth=1.7, xlim=['2020-12-01', '2023-01-01'], label='Prediction made on train data')
#      18 plt.plot(testPredictPlot, linewidth=1.7, xlim=['2020-12-01', '2023-01-01'], label='Prediction made on test data')
#      20 plt.title('Microsoft Stock Price Prediction')
#
# File ~/anaconda3/envs/tfEnv/lib/python3.10/site-packages/matplotlib/pyplot.py:2769, in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/anaconda3/envs/tfEnv/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
#    1631 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
#    1634     self.add_line(line)
#
# File ~/anaconda3/envs/tfEnv/lib/python3.10/site-packages/matplotlib/axes/_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     310     this += args[0],
#     311     args = args[1:]
# --> 312 yield from self._plot_args(this, kwargs)
#
# File ~/anaconda3/envs/tfEnv/lib/python3.10/site-packages/matplotlib/axes/_base.py:538, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     536     return list(result)
#     537 else:
# --> 538     return [l[0] for l in result]
#
# File ~/anaconda3/envs/tfEnv/lib/python3.10/site-packages/matplotlib/axes/_base.py:538, in <listcomp>(.0)
#     536     return list(result)
#     537 else:
# --> 538     return [l[0] for l in result]
#
# File ~/anaconda3/envs/tfEnv/lib/python3.10/site-packages/matplotlib/axes/_base.py:531, in <genexpr>(.0)
#     528 else:
#     529     labels = [label] * n_datasets
# --> 531 result = (make_artist(x[:, j % ncx], y[:, j % ncy], kw,
#     532                       {**kwargs, 'label': label})
#     533           for j, label in enumerate(labels))
#     535 if return_kwargs:
#     536     return list(result)
#
# File ~/anaconda3/envs/tfEnv/lib/python3.10/site-packages/matplotlib/axes/_base.py:351, in _process_plot_var_args._makeline(self, x, y, kw, kwargs)
#     349 default_dict = self._getdefaults(set(), kw)
#     350 self._setdefaults(default_dict, kw)
# --> 351 seg = mlines.Line2D(x, y, **kw)
#     352 return seg, kw
#
# File ~/anaconda3/envs/tfEnv/lib/python3.10/site-packages/matplotlib/lines.py:393, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     389 self.set_markeredgewidth(markeredgewidth)
#     391 # update kwargs before updating data to give the caller a
#     392 # chance to init axes (and hence unit support)
# --> 393 self.update(kwargs)
#     394 self.pickradius = pickradius
#     395 self.ind_offset = 0
#
# File ~/anaconda3/envs/tfEnv/lib/python3.10/site-packages/matplotlib/artist.py:1064, in Artist.update(self, props)
#    1062             func = getattr(self, f"set_{k}", None)
#    1063             if not callable(func):
# -> 1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
#    1066             ret.append(func(v))
#    1067 if ret:
#
# AttributeError: 'Line2D' object has no property 'xlim'

# %%
df.index
# Out:
# DatetimeIndex(['2017-01-18', '2017-01-19', '2017-01-20', '2017-01-23',
#                '2017-01-24', '2017-01-25', '2017-01-26', '2017-01-27',
#                '2017-01-30', '2017-01-31',
#                ...
#                '2023-01-03', '2023-01-04', '2023-01-05', '2023-01-06',
#                '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12',
#                '2023-01-13', '2023-01-17'],
#               dtype='datetime64[ns]', name='Date', length=1510, freq=None)

# %%
# plt.figure(figsize=(12,6))

# plt.plot(scaler.inverse_transform(scaled_data), color='green')
# plt.plot(train_predict_transformed, color='yellow', linewidth=1.5, label='Predicted stock price train data')
# plt.plot(test_predict_transformed, color='red', linewidth=1.5, label='Predicted stock price test data')

# plt.plot(trainy, color='green', linewidth=2,  label='Actual stock price train data');
# plt.xticks(pd.date_range('2017-01-18', '2023-01-17', freq='Y'), rotation=45);
# # plt.plot(testy, color='blue', linewidth=2, label='Actual stock price test data')

# plt.title('Microsoft Stock Price Prediction')
# plt.xlabel('Datetime')
# plt.ylabel('Microsoft stock price')
# plt.legend()

# %% [markdown]
# ## Is Microsoft stock worth buying in 2023?

# %%
from datetime import datetime

# %%
datetime.today()
# Out:
# datetime.datetime(2023, 1, 24, 16, 33, 21, 253073)

# %%
len(df.index)
# Out:
# 1510

# %%
df.index.min(), df.index.max()
# Out:
# (Timestamp('2017-01-18 00:00:00'), Timestamp('2023-01-17 00:00:00'))

# %%
pd.date_range('2017-01-18', '2023-01-17', freq='B')
# Out:
# DatetimeIndex(['2017-01-18', '2017-01-19', '2017-01-20', '2017-01-23',
#                '2017-01-24', '2017-01-25', '2017-01-26', '2017-01-27',
#                '2017-01-30', '2017-01-31',
#                ...
#                '2023-01-04', '2023-01-05', '2023-01-06', '2023-01-09',
#                '2023-01-10', '2023-01-11', '2023-01-12', '2023-01-13',
#                '2023-01-16', '2023-01-17'],
#               dtype='datetime64[ns]', length=1565, freq='B')

# %%
len(pd.date_range('2017-01-18', '2023-01-17', freq='Y'))
# Out:
# 6
