# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')
# import pandas_datareader as pdr

from datetime import datetime


warnings.filterwarnings('once')

# %% [markdown]
# The data can either be accessed using a <b>pandas_datareader</b> library or be downloaded directly in .csv formaat using the url https://finance.yahoo.com/quote/MSFT/history?period1=1516233600&period2=1674000000&interval=1d&filter=history&frequency=1d&includeAdjustedClose=true.
#
# Since currently yahoo have made some changes in their API, the code `pdr.get_data_yahoo('MSFT')` is unable to fetch the data, so we'll be working by downloading the data in csv format from the above url.

# %%
# pdr.get_data_yahoo('MSFT')

# %%
df = pd.read_csv('MSFT.csv', parse_dates=['Date'])
df.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close    Volume
# 0 2017-01-18  62.669998  62.700001  62.119999  62.500000  57.571678  19670100
# 1 2017-01-19  62.240002  62.980000  62.200001  62.299999  57.387444  18451700
# 2 2017-01-20  62.669998  62.820000  62.369999  62.740002  57.792763  30213500
# 3 2017-01-23  62.700001  63.119999  62.570000  62.959999  57.995399  23097600
# 4 2017-01-24  63.200001  63.740002  62.939999  63.520000  58.511246  24672900

# %%
df.tail()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 1505 2023-01-10  227.759995  231.309998  227.330002  228.850006  228.850006
# 1506 2023-01-11  231.289993  235.949997  231.110001  235.770004  235.770004
# 1507 2023-01-12  235.259995  239.899994  233.559998  238.509995  238.509995
# 1508 2023-01-13  237.000000  239.369995  234.919998  239.229996  239.229996
# 1509 2023-01-17  237.970001  240.910004  237.089996  240.350006  240.350006
#
#         Volume
# 1505  27033900
# 1506  28669300
# 1507  27269500
# 1508  21317700
# 1509  29831300

# %%
df.set_index('Date', inplace=True)

# %%
df.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1510 entries, 2017-01-18 to 2023-01-17
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1510 non-null   float64
#  1   High       1510 non-null   float64
#  2   Low        1510 non-null   float64
#  3   Close      1510 non-null   float64
#  4   Adj Close  1510 non-null   float64
#  5   Volume     1510 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 82.6 KB

# %%
df[df.isna().any(1)]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %% [markdown]
# None of the columns has <b>NAN</b> values here. Also type conversion of column values is not needed.

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.plot(figsize=(12,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
fig, ax = plt.subplots(4, 1, figsize=(12,20), sharex=True)

df['Open'].plot(ax=ax[0], title='Microsoft stock opening share value')
df['High'].plot(ax=ax[1], title='Microsoft stock high share value')
df['Low'].plot(ax=ax[2], title='Microsoft stock low share value')
df['Close'].plot(ax=ax[3], title='Microsoft stock closing share value')
# Out:
# <AxesSubplot:title={'center':'Microsoft stock closing share value'}, xlabel='Date'>

# %%
# let's visualize only the part of the graph on which the microsoft value goes up really high
fig, ax = plt.subplots(4, 1, figsize=(12,20), sharex=True, sharey=False)
plt.ylabel('Price USD($)')
# fig.autofmt_xdate()
# plt.tight_layout()

df['Open'].plot(ax=ax[0], xlim=['2020-12-01', '2023-01-01'], title='Microsoft stock opening share value')
df['High'].plot(ax=ax[1], xlim=['2020-12-01', '2023-01-01'], title='Microsoft stock high share value')
df['Low'].plot(ax=ax[2], xlim=['2020-12-01', '2023-01-01'], title='Microsoft stock low share value')
df['Close'].plot(ax=ax[3], xlim=['2020-12-01', '2023-01-01'], title='Microsoft stock closing share value')
# Out:
# <AxesSubplot:title={'center':'Microsoft stock closing share value'}, xlabel='Date', ylabel='Price USD($)'>

# %% [markdown]
# ## Time Resampling
# ### Upsampling

# %%
annual_stock = df.resample('A').max()
display(annual_stock)

annual_stock['Close'].plot()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-12-31   87.120003   87.500000   86.230003   86.849998   81.787941
# 2018-12-31  115.419998  116.180000  114.930000  115.610001  110.279938
# 2019-12-31  159.449997  159.550003  158.220001  158.960007  154.538162
# 2020-12-31  229.270004  232.860001  227.350006  231.649994  226.997528
# 2021-12-31  344.619995  349.670013  342.200012  343.109985  339.924805
# 2022-12-31  335.350006  338.000000  329.779999  334.750000  331.642426
# 2023-12-31  243.080002  245.750000  237.399994  240.350006  240.350006
#
#                Volume
# Date
# 2017-12-31   71066700
# 2018-12-31  111242100
# 2019-12-31   55636400
# 2020-12-31   97012700
# 2021-12-31   69870600
# 2022-12-31   90428900
# 2023-12-31   50623400
# <AxesSubplot:xlabel='Date'>

# %%
annual_stock['Close'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
annual_stock['Volume'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
quarterly_stock = df.resample('QS').max()
display(quarterly_stock.tail(10))
quarterly_stock['Close'].plot()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-10-01  226.309998  228.119995  223.580002  224.960007  221.019012
# 2021-01-01  245.029999  246.130005  242.919998  244.990005  240.698090
# 2021-04-01  270.690002  271.649994  269.600006  271.399994  267.876678
# 2021-07-01  305.019989  305.839996  302.000000  305.220001  301.834412
# 2021-10-01  344.619995  349.670013  342.200012  343.109985  339.924805
# 2022-01-01  335.350006  338.000000  329.779999  334.750000  331.642426
# 2022-04-01  313.269989  315.109985  309.869995  314.970001  312.691284
# 2022-07-01  291.989990  294.179993  290.420013  293.470001  292.025421
# 2022-10-01  261.690002  263.920013  254.309998  257.220001  257.220001
# 2023-01-01  243.080002  245.750000  237.399994  240.350006  240.350006
#
#               Volume
# Date
# 2020-10-01  63354900
# 2021-01-01  69870600
# 2021-04-01  46903100
# 2021-07-01  43186200
# 2021-10-01  52588700
# 2022-01-01  90428900
# 2022-04-01  63477700
# 2022-07-01  45994000
# 2022-10-01  86102000
# 2023-01-01  50623400
# <AxesSubplot:xlabel='Date'>

# %%
quarterly_stock['Close'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
monthly_stock = df.resample('M').max()
display(monthly_stock.head())

monthly_stock['Close'].plot()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2017-01-31  65.690002  65.910004  64.889999  65.779999  60.593033  44818000
# 2017-02-28  64.739998  65.239998  64.449997  64.720001  59.885384  45827000
# 2017-03-31  65.650002  66.190002  65.449997  65.860001  61.034527  49219700
# 2017-04-30  68.910004  69.139999  67.690002  68.459999  63.444038  39548800
# 2017-05-31  70.529999  70.739998  69.809998  70.410004  65.625160  34956000
# <AxesSubplot:xlabel='Date'>

# %%
monthly_stock['Close'].plot(kind='bar', figsize=(14,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# After exploring and visualizing the above plote we can notice that there is some upward and downward trend in our dataset. Most probably the dataset is not stationary.

# %% [markdown]
# # Stationarity Check
# ## Summary statistics and plot
# Though this is not the most rigorous method to check the stationarity of the data, it gives a good sense of whether the data is stationary or not.

# %%
df['Close'].hist()
# Out:
# <AxesSubplot:>

# %%
chunks = np.split(df['Close'], indices_or_sections=10)
print('Mean: ', np.mean(chunks, axis=1))
print('\nVariance: ',np.var(chunks, axis=1))
# Out:
# Mean:  [ 68.03966922  84.41152331 103.64410611 113.69966901 142.99715238
#  182.66649026 221.16807929 277.52960237 302.22841033 250.99344336]
#
# Variance:  [ 11.59197866  49.8547398   46.5124306   88.96238242  71.38420441
#  405.25823545 139.67014173 525.42642763 629.28894424 303.87170849]

# %% [markdown]
# To get even more sophisticated understanding of the change in mean and variance let's plot the histogram of mean and variance.

# %%
pd.Series(np.mean(chunks, axis=1)).hist();

# %%
pd.Series(np.var(chunks, axis=1)).hist();

# %% [markdown]
# For a data to be stationary, it should have constant mean and variance across the time series. But in case of our dataset, the mean and the variance is changing drastically over time which means that out data is not stationary.
#
# As this is not an accurate way to check for the stationarity of the data, let's use some statistical tests like <b>Augmeted Dickey-Fuller Test</b> to check for the stationarity.
# ### Augmented Dickey-Fuller (ADF) Test
# adfuller() returns adf, pvalue, usedlag, nobs, critical_values, icbest<br>
# <b>Null Hypothesis</b>: Series is not stationary.<br>
# <b>Alternative Hypothesis</b>: Series is stationary.<br>
# 1. If p-value < threshold, reject null hyppothesis.<br>
# 2. If p-value ≥ threshold, accept null hypothesis. <br>
#
# Generally, we take <b>0.05</b> as a threshold value.

# %%
from statsmodels.tsa.stattools import adfuller

adf, pvalue, usedlag, nobs, critical_values, icbest = adfuller(df['Close'])

# %%
def adf_test(timeseries):
    test_stat = adfuller(timeseries)
    result = pd.Series({'ADF statistic': test_stat[0],
                       'p-value': test_stat[1],
                        'Used lags': test_stat[2],
                        'Observations used': test_stat[3]})
    for key, value in test_stat[4].items():
        result['Critical value ({})'.format(key)] = value
    if test_stat[1] < 0.05:
        print("\nReject null hypothesis! Indicates that the data is stationary.")
    else:
        print("\nAccept null hypothesis! Indicates that the data is not stationary.")
    return result

# %%
adf_test(df['Close'])
# Out:
# Accept null hypothesis! Indicates that the data is not stationary.
# ADF statistic             -1.144897
# p-value                    0.696840
# Used lags                  9.000000
# Observations used       1500.000000
# Critical value (1%)       -3.434717
# Critical value (5%)       -2.863469
# Critical value (10%)      -2.567797
# dtype: float64

# %% [markdown]
# ### Kwiatkowski-Phillips-Schmidt-Shin (KPSS) Test
# ADF and KPSS has just opposite assumption. A key difference from ADF test is the null hypothesis of the KPSS test is that the series is stationary.<br><br>
# <b>Null Hypothesis</b>: Series is stationary.<br>
# <b>Alternative Hypothesis</b>: Series is not stationary.<br>
# 1. If p-value < threshold, reject null hyppothesis.<br>
# 2. If p-value ≥ threshold, accept null hypothesis. <br>
#
# Generally, we take <b>0.05</b> as a threshold value.
#
# kpss() returns kpss_stat, p_value, lags, crit

# %%
from statsmodels.tsa.stattools import kpss

kpss_stat, p_value, lags, crit = kpss(df['Close']);
# Out:
# /home/sushmita/anaconda3/envs/tfEnv/lib/python3.10/site-packages/statsmodels/tsa/stattools.py:2018: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(

# %%
def kpss_test(timeseries):
    test_stat = kpss(timeseries)
    result = pd.Series({'KPSS statistic': test_stat[0],
                       'p-value': test_stat[1],
                        'Used lags': test_stat[2]})
    for key, value in test_stat[3].items():
        result['Critical value ({})'.format(key)] = value
    if test_stat[1] < 0.05:
        print("\nReject null hypothesis! Indicates that the data is not stationary.")
    else:
        print("\nAccept null hypothesis! Indicates that the data is stationary.")
    return result

# %%
kpss_test(df['Close'])
# Out:
# Reject null hypothesis! Indicates that the data is not stationary.
# /home/sushmita/anaconda3/envs/tfEnv/lib/python3.10/site-packages/statsmodels/tsa/stattools.py:2018: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(
# KPSS statistic            5.54623
# p-value                   0.01000
# Used lags                25.00000
# Critical value (10%)      0.34700
# Critical value (5%)       0.46300
# Critical value (2.5%)     0.57400
# Critical value (1%)       0.73900
# dtype: float64

# %% [markdown]
# Both tests <b>ADF</b> and <b>KPSS</b> conclude that our data is not stationary

# %% [markdown]
# ## Smoothing
# ## Simple Moving Average

# %%
# df.drop('Open: 15 days rolling', axis=1, inplace=True)

# %%
df['Close: 15 days rolling'] = df['Close'].rolling(window=15, min_periods=2).mean()
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2017-01-18  62.669998  62.700001  62.119999  62.500000  57.571678  19670100
# 2017-01-19  62.240002  62.980000  62.200001  62.299999  57.387444  18451700
# 2017-01-20  62.669998  62.820000  62.369999  62.740002  57.792763  30213500
# 2017-01-23  62.700001  63.119999  62.570000  62.959999  57.995399  23097600
# 2017-01-24  63.200001  63.740002  62.939999  63.520000  58.511246  24672900
#
#             Close: 15 days rolling
# Date
# 2017-01-18                     NaN
# 2017-01-19               62.399999
# 2017-01-20               62.513334
# 2017-01-23               62.625000
# 2017-01-24               62.804000

# %%
df[['Close', 'Close: 15 days rolling']].plot(figsize=(12,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
adf_test(df['Close: 15 days rolling'].fillna(0))
# Out:
# Accept null hypothesis! Indicates that the data is not stationary.
# ADF statistic             -1.178981
# p-value                    0.682572
# Used lags                 23.000000
# Observations used       1486.000000
# Critical value (1%)       -3.434758
# Critical value (5%)       -2.863487
# Critical value (10%)      -2.567807
# dtype: float64

# %%
df['Close: 30 days rolling'] = df['Close'].rolling(window=30, min_periods=2).mean()
df['Close: 60 days rolling'] = df['Close'].rolling(window=60, min_periods=2).mean()

# %%
df[['Close', 'Close: 15 days rolling', 
    'Close: 30 days rolling','Close: 60 days rolling']].plot(xlim=['2019-12-01', '2023-01-01'],figsize=(12,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
adf_test(df['Close: 60 days rolling'].fillna(0))
# Out:
# Accept null hypothesis! Indicates that the data is not stationary.
# ADF statistic             -1.218854
# p-value                    0.665433
# Used lags                 10.000000
# Observations used       1499.000000
# Critical value (1%)       -3.434720
# Critical value (5%)       -2.863470
# Critical value (10%)      -2.567798
# dtype: float64

# %% [markdown]
# ## Cumulative Moving Average
# Replacing each data point in each time series by the average of the previous data points in the same time series.

# %%
df['Close'].expanding().mean().plot(figsize=(12,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Exponential Moving Average

# %%
# exponential moving average
# alpha here is smoothening parameter
df['EWM_0.1'] = df['Close'].ewm(alpha=0.1, adjust=False).mean()
df['EWM_0.3'] = df['Close'].ewm(alpha=0.3, adjust=False).mean()

df[['Close', 'EWM_0.1', 'EWM_0.3']].plot(figsize=(12,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Line with smoothening parameter (alpha) 0.3 is looking better than 0.1 as it is more towards the original data points.

# %%
# df.drop(['EWMA_5days', 'EWMA_10days'], inplace=True, axis=1)

# %%
# exponential weighted moving average of 5 days
# we're calculating EWMA by specifying span parameter in ewm() function
df['EWMA_5days'] = df['Close'].ewm(span=5).mean()

df[['Close', 'EWM_0.3', 'EWMA_5days']].plot(figsize=(12,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
adf_test(df['EWMA_5days'])
# Out:
# Accept null hypothesis! Indicates that the data is not stationary.
# ADF statistic             -1.136932
# p-value                    0.700122
# Used lags                 10.000000
# Observations used       1499.000000
# Critical value (1%)       -3.434720
# Critical value (5%)       -2.863470
# Critical value (10%)      -2.567798
# dtype: float64

# %% [markdown]
# Here we see that our data is still not stationary. So to make it stationary we'll use differencing.
# ## Differencing

# %%
df['Close - First order difference'] = df['Close'] - df['Close'].shift(1)

# %%
df['Close - First order difference'].head()
# Out:
# Date
# 2017-01-18         NaN
# 2017-01-19   -0.200001
# 2017-01-20    0.440003
# 2017-01-23    0.219997
# 2017-01-24    0.560001
# Name: Close - First order difference, dtype: float64

# %%
adf_test(df['Close - First order difference'].dropna())
# Out:
# Reject null hypothesis! Indicates that the data is stationary.
# ADF statistic          -1.314485e+01
# p-value                 1.405134e-24
# Used lags               8.000000e+00
# Observations used       1.500000e+03
# Critical value (1%)    -3.434717e+00
# Critical value (5%)    -2.863469e+00
# Critical value (10%)   -2.567797e+00
# dtype: float64

# %%
kpss_test(df['Close - First order difference'].dropna())
# Out:
# Accept null hypothesis! Indicates that the data is stationary.
# /home/sushmita/anaconda3/envs/tfEnv/lib/python3.10/site-packages/statsmodels/tsa/stattools.py:2022: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(
# KPSS statistic           0.127471
# p-value                  0.100000
# Used lags                5.000000
# Critical value (10%)     0.347000
# Critical value (5%)      0.463000
# Critical value (2.5%)    0.574000
# Critical value (1%)      0.739000
# dtype: float64

# %% [markdown]
# So after first order differecing both test statistics are saying that our series is stationary.

# %%
df['Close - First order difference'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Close - First order difference'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# On the above histogram we see that the series is following normal distribution after making it stationary. If the variables in the series follows gaussian distribution then the series is called Gaussian White Noise, it is random....It means all variables are independently and identically distributed with mean 0 and the same variance. Each values has 0 correlation with all other values in the series. Such data cannot be modeled and prediction cannot be made using them.

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(df['Close - First order difference']);

# %%
plot_pacf(df['Close - First order difference']);

# %% [markdown]
# ## Time Series Decomposition
# Decomposition of time series into 3 components
# 1. Trend
# 2. Seasonality
# 3. Residual

# %%
df['Close'].plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
print(df.index.freq)
# Out:
# None

# %%
[type(df.index), df.index.dtype]
# Out:
# [pandas.core.indexes.datetimes.DatetimeIndex, dtype('<M8[ns]')]

# %%
print(df.index.inferred_freq)
# Out:
# None

# %%
# Standardizing the DatetimeIndex
# The frequency of the DateTime index is None so we've to set it to some datetime period
# Our datetime index has some missing days (weekend days- saturday and sunday along with some other missing dates)
# So we'll seet the frequency as 'B' business day and treat the missing values using fillna() functio
new_index = df.asfreq('B').index
new_index
# Out:
# DatetimeIndex(['2017-01-18', '2017-01-19', '2017-01-20', '2017-01-23',
#                '2017-01-24', '2017-01-25', '2017-01-26', '2017-01-27',
#                '2017-01-30', '2017-01-31',
#                ...
#                '2023-01-04', '2023-01-05', '2023-01-06', '2023-01-09',
#                '2023-01-10', '2023-01-11', '2023-01-12', '2023-01-13',
#                '2023-01-16', '2023-01-17'],
#               dtype='datetime64[ns]', name='Date', length=1565, freq='B')

# %%
df_new = df.reindex(new_index, fill_value=np.NAN)

# %%
print(df_new.index.freq)
# Out:
# <BusinessDay>

# %%
df_new.shape[0] - df.shape[0]
# Out:
# 55

# %%
df_new[df_new.isna().any(1)]
# Out:
#                  Open       High        Low  Close  Adj Close      Volume  \
# Date
# 2017-01-18  62.669998  62.700001  62.119999   62.5  57.571678  19670100.0
# 2017-02-20        NaN        NaN        NaN    NaN        NaN         NaN
# 2017-04-14        NaN        NaN        NaN    NaN        NaN         NaN
# 2017-05-29        NaN        NaN        NaN    NaN        NaN         NaN
# 2017-07-04        NaN        NaN        NaN    NaN        NaN         NaN
# 2017-09-04        NaN        NaN        NaN    NaN        NaN         NaN
# 2017-11-23        NaN        NaN        NaN    NaN        NaN         NaN
# 2017-12-25        NaN        NaN        NaN    NaN        NaN         NaN
# 2018-01-01        NaN        NaN        NaN    NaN        NaN         NaN
# 2018-01-15        NaN        NaN        NaN    NaN        NaN         NaN
# 2018-02-19        NaN        NaN        NaN    NaN        NaN         NaN
# 2018-03-30        NaN        NaN        NaN    NaN        NaN         NaN
# 2018-05-28        NaN        NaN        NaN    NaN        NaN         NaN
# 2018-07-04        NaN        NaN        NaN    NaN        NaN         NaN
# 2018-09-03        NaN        NaN        NaN    NaN        NaN         NaN
# 2018-11-22        NaN        NaN        NaN    NaN        NaN         NaN
# 2018-12-05        NaN        NaN        NaN    NaN        NaN         NaN
# 2018-12-25        NaN        NaN        NaN    NaN        NaN         NaN
# 2019-01-01        NaN        NaN        NaN    NaN        NaN         NaN
# 2019-01-21        NaN        NaN        NaN    NaN        NaN         NaN
# 2019-02-18        NaN        NaN        NaN    NaN        NaN         NaN
# 2019-04-19        NaN        NaN        NaN    NaN        NaN         NaN
# 2019-05-27        NaN        NaN        NaN    NaN        NaN         NaN
# 2019-07-04        NaN        NaN        NaN    NaN        NaN         NaN
# 2019-09-02        NaN        NaN        NaN    NaN        NaN         NaN
# 2019-11-28        NaN        NaN        NaN    NaN        NaN         NaN
# 2019-12-25        NaN        NaN        NaN    NaN        NaN         NaN
# 2020-01-01        NaN        NaN        NaN    NaN        NaN         NaN
# 2020-01-20        NaN        NaN        NaN    NaN        NaN         NaN
# 2020-02-17        NaN        NaN        NaN    NaN        NaN         NaN
# 2020-04-10        NaN        NaN        NaN    NaN        NaN         NaN
# 2020-05-25        NaN        NaN        NaN    NaN        NaN         NaN
# 2020-07-03        NaN        NaN        NaN    NaN        NaN         NaN
# 2020-09-07        NaN        NaN        NaN    NaN        NaN         NaN
# 2020-11-26        NaN        NaN        NaN    NaN        NaN         NaN
# 2020-12-25        NaN        NaN        NaN    NaN        NaN         NaN
# 2021-01-01        NaN        NaN        NaN    NaN        NaN         NaN
# 2021-01-18        NaN        NaN        NaN    NaN        NaN         NaN
# 2021-02-15        NaN        NaN        NaN    NaN        NaN         NaN
# 2021-04-02        NaN        NaN        NaN    NaN        NaN         NaN
# 2021-05-31        NaN        NaN        NaN    NaN        NaN         NaN
# 2021-07-05        NaN        NaN        NaN    NaN        NaN         NaN
# 2021-09-06        NaN        NaN        NaN    NaN        NaN         NaN
# 2021-11-25        NaN        NaN        NaN    NaN        NaN         NaN
# 2021-12-24        NaN        NaN        NaN    NaN        NaN         NaN
# 2022-01-17        NaN        NaN        NaN    NaN        NaN         NaN
# 2022-02-21        NaN        NaN        NaN    NaN        NaN         NaN
# 2022-04-15        NaN        NaN        NaN    NaN        NaN         NaN
# 2022-05-30        NaN        NaN        NaN    NaN        NaN         NaN
# 2022-06-20        NaN        NaN        NaN    NaN        NaN         NaN
# 2022-07-04        NaN        NaN        NaN    NaN        NaN         NaN
# 2022-09-05        NaN        NaN        NaN    NaN        NaN         NaN
# 2022-11-24        NaN        NaN        NaN    NaN        NaN         NaN
# 2022-12-26        NaN        NaN        NaN    NaN        NaN         NaN
# 2023-01-02        NaN        NaN        NaN    NaN        NaN         NaN
# 2023-01-16        NaN        NaN        NaN    NaN        NaN         NaN
#
#             Close: 15 days rolling  Close: 30 days rolling  \
# Date
# 2017-01-18                     NaN                     NaN
# 2017-02-20                     NaN                     NaN
# 2017-04-14                     NaN                     NaN
# 2017-05-29                     NaN                     NaN
# 2017-07-04                     NaN                     NaN
# 2017-09-04                     NaN                     NaN
# 2017-11-23                     NaN                     NaN
# 2017-12-25                     NaN                     NaN
# 2018-01-01                     NaN                     NaN
# 2018-01-15                     NaN                     NaN
# 2018-02-19                     NaN                     NaN
# 2018-03-30                     NaN                     NaN
# 2018-05-28                     NaN                     NaN
# 2018-07-04                     NaN                     NaN
# 2018-09-03                     NaN                     NaN
# 2018-11-22                     NaN                     NaN
# 2018-12-05                     NaN                     NaN
# 2018-12-25                     NaN                     NaN
# 2019-01-01                     NaN                     NaN
# 2019-01-21                     NaN                     NaN
# 2019-02-18                     NaN                     NaN
# 2019-04-19                     NaN                     NaN
# 2019-05-27                     NaN                     NaN
# 2019-07-04                     NaN                     NaN
# 2019-09-02                     NaN                     NaN
# 2019-11-28                     NaN                     NaN
# 2019-12-25                     NaN                     NaN
# 2020-01-01                     NaN                     NaN
# 2020-01-20                     NaN                     NaN
# 2020-02-17                     NaN                     NaN
# 2020-04-10                     NaN                     NaN
# 2020-05-25                     NaN                     NaN
# 2020-07-03                     NaN                     NaN
# 2020-09-07                     NaN                     NaN
# 2020-11-26                     NaN                     NaN
# 2020-12-25                     NaN                     NaN
# 2021-01-01                     NaN                     NaN
# 2021-01-18                     NaN                     NaN
# 2021-02-15                     NaN                     NaN
# 2021-04-02                     NaN                     NaN
# 2021-05-31                     NaN                     NaN
# 2021-07-05                     NaN                     NaN
# 2021-09-06                     NaN                     NaN
# 2021-11-25                     NaN                     NaN
# 2021-12-24                     NaN                     NaN
# 2022-01-17                     NaN                     NaN
# 2022-02-21                     NaN                     NaN
# 2022-04-15                     NaN                     NaN
# 2022-05-30                     NaN                     NaN
# 2022-06-20                     NaN                     NaN
# 2022-07-04                     NaN                     NaN
# 2022-09-05                     NaN                     NaN
# 2022-11-24                     NaN                     NaN
# 2022-12-26                     NaN                     NaN
# 2023-01-02                     NaN                     NaN
# 2023-01-16                     NaN                     NaN
#
#             Close: 60 days rolling  EWM_0.1  EWM_0.3  EWMA_5days  \
# Date
# 2017-01-18                     NaN     62.5     62.5        62.5
# 2017-02-20                     NaN      NaN      NaN         NaN
# 2017-04-14                     NaN      NaN      NaN         NaN
# 2017-05-29                     NaN      NaN      NaN         NaN
# 2017-07-04                     NaN      NaN      NaN         NaN
# 2017-09-04                     NaN      NaN      NaN         NaN
# 2017-11-23                     NaN      NaN      NaN         NaN
# 2017-12-25                     NaN      NaN      NaN         NaN
# 2018-01-01                     NaN      NaN      NaN         NaN
# 2018-01-15                     NaN      NaN      NaN         NaN
# 2018-02-19                     NaN      NaN      NaN         NaN
# 2018-03-30                     NaN      NaN      NaN         NaN
# 2018-05-28                     NaN      NaN      NaN         NaN
# 2018-07-04                     NaN      NaN      NaN         NaN
# 2018-09-03                     NaN      NaN      NaN         NaN
# 2018-11-22                     NaN      NaN      NaN         NaN
# 2018-12-05                     NaN      NaN      NaN         NaN
# 2018-12-25                     NaN      NaN      NaN         NaN
# 2019-01-01                     NaN      NaN      NaN         NaN
# 2019-01-21                     NaN      NaN      NaN         NaN
# 2019-02-18                     NaN      NaN      NaN         NaN
# 2019-04-19                     NaN      NaN      NaN         NaN
# 2019-05-27                     NaN      NaN      NaN         NaN
# 2019-07-04                     NaN      NaN      NaN         NaN
# 2019-09-02                     NaN      NaN      NaN         NaN
# 2019-11-28                     NaN      NaN      NaN         NaN
# 2019-12-25                     NaN      NaN      NaN         NaN
# 2020-01-01                     NaN      NaN      NaN         NaN
# 2020-01-20                     NaN      NaN      NaN         NaN
# 2020-02-17                     NaN      NaN      NaN         NaN
# 2020-04-10                     NaN      NaN      NaN         NaN
# 2020-05-25                     NaN      NaN      NaN         NaN
# 2020-07-03                     NaN      NaN      NaN         NaN
# 2020-09-07                     NaN      NaN      NaN         NaN
# 2020-11-26                     NaN      NaN      NaN         NaN
# 2020-12-25                     NaN      NaN      NaN         NaN
# 2021-01-01                     NaN      NaN      NaN         NaN
# 2021-01-18                     NaN      NaN      NaN         NaN
# 2021-02-15                     NaN      NaN      NaN         NaN
# 2021-04-02                     NaN      NaN      NaN         NaN
# 2021-05-31                     NaN      NaN      NaN         NaN
# 2021-07-05                     NaN      NaN      NaN         NaN
# 2021-09-06                     NaN      NaN      NaN         NaN
# 2021-11-25                     NaN      NaN      NaN         NaN
# 2021-12-24                     NaN      NaN      NaN         NaN
# 2022-01-17                     NaN      NaN      NaN         NaN
# 2022-02-21                     NaN      NaN      NaN         NaN
# 2022-04-15                     NaN      NaN      NaN         NaN
# 2022-05-30                     NaN      NaN      NaN         NaN
# 2022-06-20                     NaN      NaN      NaN         NaN
# 2022-07-04                     NaN      NaN      NaN         NaN
# 2022-09-05                     NaN      NaN      NaN         NaN
# 2022-11-24                     NaN      NaN      NaN         NaN
# 2022-12-26                     NaN      NaN      NaN         NaN
# 2023-01-02                     NaN      NaN      NaN         NaN
# 2023-01-16                     NaN      NaN      NaN         NaN
#
#             Close - First order difference
# Date
# 2017-01-18                             NaN
# 2017-02-20                             NaN
# 2017-04-14                             NaN
# 2017-05-29                             NaN
# 2017-07-04                             NaN
# 2017-09-04                             NaN
# 2017-11-23                             NaN
# 2017-12-25                             NaN
# 2018-01-01                             NaN
# 2018-01-15                             NaN
# 2018-02-19                             NaN
# 2018-03-30                             NaN
# 2018-05-28                             NaN
# 2018-07-04                             NaN
# 2018-09-03                             NaN
# 2018-11-22                             NaN
# 2018-12-05                             NaN
# 2018-12-25                             NaN
# 2019-01-01                             NaN
# 2019-01-21                             NaN
# 2019-02-18                             NaN
# 2019-04-19                             NaN
# 2019-05-27                             NaN
# 2019-07-04                             NaN
# 2019-09-02                             NaN
# 2019-11-28                             NaN
# 2019-12-25                             NaN
# 2020-01-01                             NaN
# 2020-01-20                             NaN
# 2020-02-17                             NaN
# 2020-04-10                             NaN
# 2020-05-25                             NaN
# 2020-07-03                             NaN
# 2020-09-07                             NaN
# 2020-11-26                             NaN
# 2020-12-25                             NaN
# 2021-01-01                             NaN
# 2021-01-18                             NaN
# 2021-02-15                             NaN
# 2021-04-02                             NaN
# 2021-05-31                             NaN
# 2021-07-05                             NaN
# 2021-09-06                             NaN
# 2021-11-25                             NaN
# 2021-12-24                             NaN
# 2022-01-17                             NaN
# 2022-02-21                             NaN
# 2022-04-15                             NaN
# 2022-05-30                             NaN
# 2022-06-20                             NaN
# 2022-07-04                             NaN
# 2022-09-05                             NaN
# 2022-11-24                             NaN
# 2022-12-26                             NaN
# 2023-01-02                             NaN
# 2023-01-16                             NaN

# %% [markdown]
# #### Now let's fill these missing NaN values using fillna() function. But we're not gonna replace the missing values of the very first row because those NaN values were formed as a result of smoothing process.

# %%
df_new.fillna(method='pad', inplace=True, axis=0) 
# pad method propagates the last valid observation to the missing value rowwise

# %%
df_new[df_new.isna().any(1)]
# since the pad method donot find any values before the very first NaN values, it left the NaN values as it is
# Out:
#                  Open       High        Low  Close  Adj Close      Volume  \
# Date
# 2017-01-18  62.669998  62.700001  62.119999   62.5  57.571678  19670100.0
#
#             Close: 15 days rolling  Close: 30 days rolling  \
# Date
# 2017-01-18                     NaN                     NaN
#
#             Close: 60 days rolling  EWM_0.1  EWM_0.3  EWMA_5days  \
# Date
# 2017-01-18                     NaN     62.5     62.5        62.5
#
#             Close - First order difference
# Date
# 2017-01-18                             NaN

# %%
df_new.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Close: 15 days rolling', 'Close: 30 days rolling',
#        'Close: 60 days rolling', 'EWM_0.1', 'EWM_0.3', 'EWMA_5days',
#        'Close - First order difference'],
#       dtype='object')

# %%
# df_new.drop(['Open: 15 days rolling', 'Open: 30 days rolling', 
#             'Open: 60 days rolling', 'EWM_0.1', 'EWM_0.3', 'EWMA_5days'], inplace=True, axis=1)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

#since the magnitude of seasonal values in our dataset is independent of trend we'll use additive decomposition
decomposition_result = seasonal_decompose(x=df_new['Close'], model='additive')
fig, ax = plt.subplots(4,1, sharex=True)
fig.set_figheight(15)
fig.set_figwidth(10)

ax[0].plot(df_new['Close'])
ax[0].title.set_text('Original data')

ax[1].plot(decomposition_result.trend)
ax[1].title.set_text('Trend')

ax[2].plot(decomposition_result.seasonal)
ax[2].title.set_text('Seasonality')

ax[3].plot(decomposition_result.resid)
ax[3].title.set_text('Residual obtained after removing trend and seasonality')

# %%
df_new[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']].plot(figsize=(12,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
adf_test(decomposition_result.resid.fillna(0))
# Out:
# Reject null hypothesis! Indicates that the data is stationary.
# ADF statistic          -1.389318e+01
# p-value                 5.916518e-26
# Used lags               2.200000e+01
# Observations used       1.542000e+03
# Critical value (1%)    -3.434598e+00
# Critical value (5%)    -2.863416e+00
# Critical value (10%)   -2.567769e+00
# dtype: float64

# %%
adf_test(decomposition_result.resid.dropna())
# Out:
# Reject null hypothesis! Indicates that the data is stationary.
# ADF statistic          -1.386230e+01
# p-value                 6.694628e-26
# Used lags               2.200000e+01
# Observations used       1.538000e+03
# Critical value (1%)    -3.434609e+00
# Critical value (5%)    -2.863421e+00
# Critical value (10%)   -2.567771e+00
# dtype: float64

# %%
plot_acf(decomposition_result.resid);
plot_pacf(decomposition_result.resid);

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
new_df = data.reset_index()
new_df = new_df[['Open', 'High', 'Low', 'Close', 'Volume']]

# %%
new_df.head()
# Out:
#         Open       High        Low      Close    Volume
# 0  62.669998  62.700001  62.119999  62.500000  19670100
# 1  62.240002  62.980000  62.200001  62.299999  18451700
# 2  62.669998  62.820000  62.369999  62.740002  30213500
# 3  62.700001  63.119999  62.570000  62.959999  23097600
# 4  63.200001  63.740002  62.939999  63.520000  24672900

# %%
X = new_df[['Open', 'High', 'Low', 'Volume']]
y = new_df['Close']

# %%
train, test = train_test_split(new_df, test_size=0.3, random_state=0, shuffle=False)
xtrain = train[['Open', 'High', 'Low', 'Volume']]
ytrain = train['Close']

xtest = test[['Open', 'High', 'Low', 'Volume']]
ytest = test['Close']

# %%
reg = LinearRegression()
reg.fit(xtrain, ytrain)

# %%
ypredicted = reg.predict(xtest)
rmse = np.sqrt(mean_squared_error(ytest, ypredicted))
print(rmse)

# %%
df_pred = pd.DataFrame({'Actual': ytest, 'Predicted': ypredicted})
df_pred.head()
# Out:
#           Actual   Predicted
# 1057  235.770004  237.452349
# 1058  242.350006  241.748763
# 1059  249.070007  248.506372
# 1060  247.860001  248.671694
# 1061  249.899994  249.999668

# %%
plt.plot(df_pred['Actual'], color='green', linewidth=2)
plt.plot(df_pred['Predicted'], color='yellow', linewidth=2)

# %%
df_lstm[:20].plot(kind='bar', figsize=(12,7))
# Out:
# <AxesSubplot:>

# %%
df_lstm[-20:].plot(kind='bar', figsize=(12,7))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## DeepLearning -- LSTM

# %%
data = df['Close']
data = data.reset_index()
data.drop('Date', axis=1, inplace=True)
data.head()
# Out:
#        Close
# 0  62.500000
# 1  62.299999
# 2  62.740002
# 3  62.959999
# 4  63.520000

# %%
# Scale data
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(np.array(data))

# %%
scaled_data.shape
# Out:
# (1510, 1)

# %%
train_size = int(len(data)*0.70)
test_size = len(data) - train_size

train_set, test_set = scaled_data[0:train_size, :], scaled_data[train_size:scaled_data.shape[0], :]

# %%
train_set.shape, test_set.shape
# Out:
# ((1057, 1), (453, 1))

# %%
type(train_set)
# Out:
# numpy.ndarray

# %%
# def  get_train_test_data(dataset, timestamp=1):
#     data_X = []
#     data_y = []
#     for i in range(timestamp, len(dataset)):
#         data_X.append(train_set[i-timestamp:i, 0])
#         data_y.append(train_set[i, 0])
#     return np.array(data_X), np.array(data_y)

# %%
def get_train_test_data(dataset, timestamp=1):
    dataX = []
    dataY = []
    for i in range(len(dataset)-timestamp-1):
        a = dataset[i:(i+timestamp), 0] 
        dataX.append(a)
        dataY.append(dataset[i + timestamp, 0])
    return np.array(dataX), np.array(dataY)

# %%
trainx , trainy = get_train_test_data(train_set, timestamp=60)

# %%
trainx.shape, trainy.shape
# Out:
# ((996, 60), (996,))

# %%
testx, testy = get_train_test_data(test_set, timestamp=60)

# %%
testx.shape, testy.shape
# Out:
# ((392, 60), (392,))

# %%
# reshape the data to [sample_size, time_step, features], here we're working with only 1 feature i.e. Close
train_X = trainx.reshape(trainx.shape[0], trainx.shape[1], 1)
test_X = testx.reshape(testx.shape[0], testx.shape[1], 1)

# %%
train_X.shape, test_X.shape
# Out:
# ((996, 60, 1), (392, 60, 1))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# Build LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (train_X.shape[1],1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# %%
# Compile the model
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 50)            10400
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 25)                1275
#
#  dense_1 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 31,901
# Trainable params: 31,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
# stop the training when there is no improvement in the loss for 100 consecutive epoch
# and save the best model observed during training for later use

callbacks = [EarlyStopping(monitor='val_loss', mode='min', patience=10, verbose=1),
            ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)]
                         
# fit the model
history = model.fit(train_X, trainy, epochs=100, batch_size=32, 
                    callbacks=callbacks, validation_data=(test_X, testy))
# Out:
# Epoch 1/100
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0093
# Epoch 1: val_loss improved from inf to 0.00204, saving model to best_model.h5
# 32/32 [==============================] - 4s 47ms/step - loss: 0.0090 - val_loss: 0.0020
# Epoch 2/100
# 31/32 [============================>.] - ETA: 0s - loss: 4.6078e-04
# Epoch 2: val_loss improved from 0.00204 to 0.00175, saving model to best_model.h5
# 32/32 [==============================] - 1s 30ms/step - loss: 4.6442e-04 - val_loss: 0.0018
# Epoch 3/100
# 31/32 [============================>.] - ETA: 0s - loss: 3.4676e-04
# Epoch 3: val_loss improved from 0.00175 to 0.00151, saving model to best_model.h5
# 32/32 [==============================] - 1s 30ms/step - loss: 3.4729e-04 - val_loss: 0.0015
# Epoch 4/100
# 31/32 [============================>.] - ETA: 0s - loss: 3.1411e-04
# Epoch 4: val_loss did not improve from 0.00151
# 32/32 [==============================] - 1s 28ms/step - loss: 3.1309e-04 - val_loss: 0.0015
# Epoch 5/100
# 30/32 [===========================>..] - ETA: 0s - loss: 3.1427e-04
# Epoch 5: val_loss improved from 0.00151 to 0.00149, saving model to best_model.h5
# 32/32 [==============================] - 1s 28ms/step - loss: 3.1101e-04 - val_loss: 0.0015
# Epoch 6/100
# 31/32 [============================>.] - ETA: 0s - loss: 3.2267e-04
# Epoch 6: val_loss did not improve from 0.00149
# 32/32 [==============================] - 1s 27ms/step - loss: 3.2236e-04 - val_loss: 0.0015
# Epoch 7/100
# 30/32 [===========================>..] - ETA: 0s - loss: 3.1760e-04
# Epoch 7: val_loss did not improve from 0.00149
# 32/32 [==============================] - 1s 27ms/step - loss: 3.1603e-04 - val_loss: 0.0021
# Epoch 8/100
# 31/32 [============================>.] - ETA: 0s - loss: 3.3898e-04
# Epoch 8: val_loss improved from 0.00149 to 0.00143, saving model to best_model.h5
# 32/32 [==============================] - 1s 31ms/step - loss: 3.3800e-04 - val_loss: 0.0014
# Epoch 9/100
# 30/32 [===========================>..] - ETA: 0s - loss: 3.0935e-04
# Epoch 9: val_loss improved from 0.00143 to 0.00138, saving model to best_model.h5
# 32/32 [==============================] - 1s 28ms/step - loss: 3.0295e-04 - val_loss: 0.0014
# Epoch 10/100
# 32/32 [==============================] - ETA: 0s - loss: 3.0104e-04
# Epoch 10: val_loss did not improve from 0.00138
# 32/32 [==============================] - 1s 27ms/step - loss: 3.0104e-04 - val_loss: 0.0018
# Epoch 11/100
# 30/32 [===========================>..] - ETA: 0s - loss: 3.1007e-04
# Epoch 11: val_loss improved from 0.00138 to 0.00135, saving model to best_model.h5
# 32/32 [==============================] - 1s 28ms/step - loss: 3.1117e-04 - val_loss: 0.0013
# Epoch 12/100
# 30/32 [===========================>..] - ETA: 0s - loss: 2.7362e-04
# Epoch 12: val_loss did not improve from 0.00135
# 32/32 [==============================] - 1s 28ms/step - loss: 2.7542e-04 - val_loss: 0.0017
# Epoch 13/100
# 30/32 [===========================>..] - ETA: 0s - loss: 3.2815e-04
# Epoch 13: val_loss did not improve from 0.00135
# 32/32 [==============================] - 1s 28ms/step - loss: 3.2390e-04 - val_loss: 0.0017
# Epoch 14/100
# 30/32 [===========================>..] - ETA: 0s - loss: 2.9808e-04
# Epoch 14: val_loss did not improve from 0.00135
# 32/32 [==============================] - 1s 31ms/step - loss: 3.0107e-04 - val_loss: 0.0026
# Epoch 15/100
# 31/32 [============================>.] - ETA: 0s - loss: 3.0841e-04
# Epoch 15: val_loss improved from 0.00135 to 0.00125, saving model to best_model.h5
# 32/32 [==============================] - 1s 30ms/step - loss: 3.0883e-04 - val_loss: 0.0013
# Epoch 16/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.6594e-04
# Epoch 16: val_loss did not improve from 0.00125
# 32/32 [==============================] - 1s 29ms/step - loss: 2.6631e-04 - val_loss: 0.0013
# Epoch 17/100
# 30/32 [===========================>..] - ETA: 0s - loss: 2.6346e-04
# Epoch 17: val_loss improved from 0.00125 to 0.00117, saving model to best_model.h5
# 32/32 [==============================] - 1s 28ms/step - loss: 2.6421e-04 - val_loss: 0.0012
# Epoch 18/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.7173e-04
# Epoch 18: val_loss did not improve from 0.00117
# 32/32 [==============================] - 1s 28ms/step - loss: 2.7115e-04 - val_loss: 0.0014
# Epoch 19/100
# 32/32 [==============================] - ETA: 0s - loss: 2.5927e-04
# Epoch 19: val_loss did not improve from 0.00117
# 32/32 [==============================] - 1s 28ms/step - loss: 2.5927e-04 - val_loss: 0.0012
# Epoch 20/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.4672e-04
# Epoch 20: val_loss improved from 0.00117 to 0.00116, saving model to best_model.h5
# 32/32 [==============================] - 1s 28ms/step - loss: 2.4596e-04 - val_loss: 0.0012
# Epoch 21/100
# 32/32 [==============================] - ETA: 0s - loss: 2.5775e-04
# Epoch 21: val_loss improved from 0.00116 to 0.00106, saving model to best_model.h5
# 32/32 [==============================] - 1s 28ms/step - loss: 2.5775e-04 - val_loss: 0.0011
# Epoch 22/100
# 32/32 [==============================] - ETA: 0s - loss: 2.3202e-04
# Epoch 22: val_loss did not improve from 0.00106
# 32/32 [==============================] - 1s 27ms/step - loss: 2.3202e-04 - val_loss: 0.0020
# Epoch 23/100
# 32/32 [==============================] - ETA: 0s - loss: 2.6550e-04
# Epoch 23: val_loss did not improve from 0.00106
# 32/32 [==============================] - 1s 27ms/step - loss: 2.6550e-04 - val_loss: 0.0012
# Epoch 24/100
# 32/32 [==============================] - ETA: 0s - loss: 2.3688e-04
# Epoch 24: val_loss did not improve from 0.00106
# 32/32 [==============================] - 1s 28ms/step - loss: 2.3688e-04 - val_loss: 0.0012
# Epoch 25/100
# 30/32 [===========================>..] - ETA: 0s - loss: 2.4996e-04
# Epoch 25: val_loss improved from 0.00106 to 0.00093, saving model to best_model.h5
# 32/32 [==============================] - 1s 30ms/step - loss: 2.5013e-04 - val_loss: 9.2982e-04
# Epoch 26/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.2250e-04
# Epoch 26: val_loss improved from 0.00093 to 0.00092, saving model to best_model.h5
# 32/32 [==============================] - 1s 29ms/step - loss: 2.2343e-04 - val_loss: 9.1688e-04
# Epoch 27/100
# 30/32 [===========================>..] - ETA: 0s - loss: 2.3259e-04
# Epoch 27: val_loss did not improve from 0.00092
# 32/32 [==============================] - 1s 29ms/step - loss: 2.2829e-04 - val_loss: 0.0011
# Epoch 28/100
# 30/32 [===========================>..] - ETA: 0s - loss: 2.2319e-04
# Epoch 28: val_loss did not improve from 0.00092
# 32/32 [==============================] - 1s 29ms/step - loss: 2.2064e-04 - val_loss: 0.0014
# Epoch 29/100
# 30/32 [===========================>..] - ETA: 0s - loss: 2.2549e-04
# Epoch 29: val_loss improved from 0.00092 to 0.00087, saving model to best_model.h5
# 32/32 [==============================] - 1s 30ms/step - loss: 2.2491e-04 - val_loss: 8.7478e-04
# Epoch 30/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.2700e-04
# Epoch 30: val_loss did not improve from 0.00087
# 32/32 [==============================] - 1s 30ms/step - loss: 2.2920e-04 - val_loss: 9.6757e-04
# Epoch 31/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.3805e-04
# Epoch 31: val_loss did not improve from 0.00087
# 32/32 [==============================] - 1s 30ms/step - loss: 2.3929e-04 - val_loss: 0.0012
# Epoch 32/100
# 30/32 [===========================>..] - ETA: 0s - loss: 2.9160e-04
# Epoch 32: val_loss did not improve from 0.00087
# 32/32 [==============================] - 1s 30ms/step - loss: 2.8960e-04 - val_loss: 0.0016
# Epoch 33/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.4831e-04
# Epoch 33: val_loss improved from 0.00087 to 0.00083, saving model to best_model.h5
# 32/32 [==============================] - 1s 32ms/step - loss: 2.4873e-04 - val_loss: 8.3076e-04
# Epoch 34/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.0704e-04
# Epoch 34: val_loss did not improve from 0.00083
# 32/32 [==============================] - 1s 31ms/step - loss: 2.0626e-04 - val_loss: 0.0015
# Epoch 35/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.1617e-04
# Epoch 35: val_loss did not improve from 0.00083
# 32/32 [==============================] - 1s 30ms/step - loss: 2.1560e-04 - val_loss: 0.0014
# Epoch 36/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.6748e-04
# Epoch 36: val_loss did not improve from 0.00083
# 32/32 [==============================] - 1s 29ms/step - loss: 1.6727e-04 - val_loss: 0.0013
# Epoch 37/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.7302e-04
# Epoch 37: val_loss did not improve from 0.00083
# 32/32 [==============================] - 1s 29ms/step - loss: 1.7253e-04 - val_loss: 9.3665e-04
# Epoch 38/100
# 32/32 [==============================] - ETA: 0s - loss: 1.8433e-04
# Epoch 38: val_loss improved from 0.00083 to 0.00076, saving model to best_model.h5
# 32/32 [==============================] - 1s 30ms/step - loss: 1.8433e-04 - val_loss: 7.6309e-04
# Epoch 39/100
# 32/32 [==============================] - ETA: 0s - loss: 1.7876e-04
# Epoch 39: val_loss improved from 0.00076 to 0.00076, saving model to best_model.h5
# 32/32 [==============================] - 1s 28ms/step - loss: 1.7876e-04 - val_loss: 7.5540e-04
# Epoch 40/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.9773e-04
# Epoch 40: val_loss did not improve from 0.00076
# 32/32 [==============================] - 1s 27ms/step - loss: 1.9439e-04 - val_loss: 7.5792e-04
# Epoch 41/100
# 32/32 [==============================] - ETA: 0s - loss: 1.9717e-04
# Epoch 41: val_loss did not improve from 0.00076
# 32/32 [==============================] - 1s 28ms/step - loss: 1.9717e-04 - val_loss: 7.8683e-04
# Epoch 42/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.7013e-04
# Epoch 42: val_loss did not improve from 0.00076
# 32/32 [==============================] - 1s 28ms/step - loss: 1.7093e-04 - val_loss: 0.0019
# Epoch 43/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.2464e-04
# Epoch 43: val_loss did not improve from 0.00076
# 32/32 [==============================] - 1s 29ms/step - loss: 2.2638e-04 - val_loss: 0.0014
# Epoch 44/100
# 32/32 [==============================] - ETA: 0s - loss: 1.7391e-04
# Epoch 44: val_loss improved from 0.00076 to 0.00072, saving model to best_model.h5
# 32/32 [==============================] - 1s 29ms/step - loss: 1.7391e-04 - val_loss: 7.2042e-04
# Epoch 45/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.6122e-04
# Epoch 45: val_loss did not improve from 0.00072
# 32/32 [==============================] - 1s 28ms/step - loss: 1.5805e-04 - val_loss: 7.4986e-04
# Epoch 46/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.6092e-04
# Epoch 46: val_loss improved from 0.00072 to 0.00070, saving model to best_model.h5
# 32/32 [==============================] - 1s 31ms/step - loss: 1.6210e-04 - val_loss: 7.0046e-04
# Epoch 47/100
# 32/32 [==============================] - ETA: 0s - loss: 1.8628e-04
# Epoch 47: val_loss did not improve from 0.00070
# 32/32 [==============================] - 1s 30ms/step - loss: 1.8628e-04 - val_loss: 0.0015
# Epoch 48/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.6839e-04
# Epoch 48: val_loss did not improve from 0.00070
# 32/32 [==============================] - 1s 31ms/step - loss: 1.6776e-04 - val_loss: 7.4631e-04
# Epoch 49/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.5444e-04
# Epoch 49: val_loss did not improve from 0.00070
# 32/32 [==============================] - 1s 32ms/step - loss: 1.5430e-04 - val_loss: 7.9975e-04
# Epoch 50/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.6638e-04
# Epoch 50: val_loss did not improve from 0.00070
# 32/32 [==============================] - 1s 30ms/step - loss: 1.6640e-04 - val_loss: 8.5845e-04
# Epoch 51/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.5954e-04
# Epoch 51: val_loss did not improve from 0.00070
# 32/32 [==============================] - 1s 29ms/step - loss: 1.5917e-04 - val_loss: 8.9464e-04
# Epoch 52/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.4307e-04
# Epoch 52: val_loss did not improve from 0.00070
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4311e-04 - val_loss: 0.0013
# Epoch 53/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.9760e-04
# Epoch 53: val_loss improved from 0.00070 to 0.00067, saving model to best_model.h5
# 32/32 [==============================] - 1s 31ms/step - loss: 1.9690e-04 - val_loss: 6.6982e-04
# Epoch 54/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.6064e-04
# Epoch 54: val_loss did not improve from 0.00067
# 32/32 [==============================] - 1s 30ms/step - loss: 1.6078e-04 - val_loss: 6.9908e-04
# Epoch 55/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.6307e-04
# Epoch 55: val_loss improved from 0.00067 to 0.00066, saving model to best_model.h5
# 32/32 [==============================] - 1s 30ms/step - loss: 1.6177e-04 - val_loss: 6.6192e-04
# Epoch 56/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.6309e-04
# Epoch 56: val_loss improved from 0.00066 to 0.00061, saving model to best_model.h5
# 32/32 [==============================] - 1s 29ms/step - loss: 1.6266e-04 - val_loss: 6.1420e-04
# Epoch 57/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.4912e-04
# Epoch 57: val_loss did not improve from 0.00061
# 32/32 [==============================] - 1s 32ms/step - loss: 1.5799e-04 - val_loss: 6.1900e-04
# Epoch 58/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.5962e-04
# Epoch 58: val_loss did not improve from 0.00061
# 32/32 [==============================] - 1s 30ms/step - loss: 1.5934e-04 - val_loss: 9.5744e-04
# Epoch 59/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.7819e-04
# Epoch 59: val_loss improved from 0.00061 to 0.00059, saving model to best_model.h5
# 32/32 [==============================] - 1s 29ms/step - loss: 1.7613e-04 - val_loss: 5.8701e-04
# Epoch 60/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.4589e-04
# Epoch 60: val_loss did not improve from 0.00059
# 32/32 [==============================] - 1s 28ms/step - loss: 1.4492e-04 - val_loss: 0.0010
# Epoch 61/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.6317e-04
# Epoch 61: val_loss improved from 0.00059 to 0.00058, saving model to best_model.h5
# 32/32 [==============================] - 1s 29ms/step - loss: 1.6085e-04 - val_loss: 5.7769e-04
# Epoch 62/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.2779e-04
# Epoch 62: val_loss did not improve from 0.00058
# 32/32 [==============================] - 1s 28ms/step - loss: 1.2730e-04 - val_loss: 6.0445e-04
# Epoch 63/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.2494e-04
# Epoch 63: val_loss improved from 0.00058 to 0.00055, saving model to best_model.h5
# 32/32 [==============================] - 1s 29ms/step - loss: 1.2497e-04 - val_loss: 5.5283e-04
# Epoch 64/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.2991e-04
# Epoch 64: val_loss did not improve from 0.00055
# 32/32 [==============================] - 1s 28ms/step - loss: 1.3000e-04 - val_loss: 6.0277e-04
# Epoch 65/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.0938e-04
# Epoch 65: val_loss did not improve from 0.00055
# 32/32 [==============================] - 1s 28ms/step - loss: 2.0891e-04 - val_loss: 7.3084e-04
# Epoch 66/100
# 32/32 [==============================] - ETA: 0s - loss: 1.4765e-04
# Epoch 66: val_loss improved from 0.00055 to 0.00055, saving model to best_model.h5
# 32/32 [==============================] - 1s 30ms/step - loss: 1.4765e-04 - val_loss: 5.4635e-04
# Epoch 67/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.2054e-04
# Epoch 67: val_loss did not improve from 0.00055
# 32/32 [==============================] - 1s 29ms/step - loss: 1.2056e-04 - val_loss: 5.4854e-04
# Epoch 68/100
# 32/32 [==============================] - ETA: 0s - loss: 1.2126e-04
# Epoch 68: val_loss did not improve from 0.00055
# 32/32 [==============================] - 1s 29ms/step - loss: 1.2126e-04 - val_loss: 6.3612e-04
# Epoch 69/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.4938e-04
# Epoch 69: val_loss improved from 0.00055 to 0.00052, saving model to best_model.h5
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4627e-04 - val_loss: 5.2263e-04
# Epoch 70/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.2445e-04
# Epoch 70: val_loss did not improve from 0.00052
# 32/32 [==============================] - 1s 29ms/step - loss: 1.2791e-04 - val_loss: 9.3355e-04
# Epoch 71/100
# 32/32 [==============================] - ETA: 0s - loss: 1.3670e-04
# Epoch 71: val_loss did not improve from 0.00052
# 32/32 [==============================] - 1s 28ms/step - loss: 1.3670e-04 - val_loss: 0.0010
# Epoch 72/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.6426e-04
# Epoch 72: val_loss did not improve from 0.00052
# 32/32 [==============================] - 1s 28ms/step - loss: 2.6476e-04 - val_loss: 5.4233e-04
# Epoch 73/100
# 32/32 [==============================] - ETA: 0s - loss: 1.4534e-04
# Epoch 73: val_loss did not improve from 0.00052
# 32/32 [==============================] - 1s 28ms/step - loss: 1.4534e-04 - val_loss: 5.5149e-04
# Epoch 74/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.2556e-04
# Epoch 74: val_loss improved from 0.00052 to 0.00051, saving model to best_model.h5
# 32/32 [==============================] - 1s 30ms/step - loss: 1.2780e-04 - val_loss: 5.1145e-04
# Epoch 75/100
# 32/32 [==============================] - ETA: 0s - loss: 1.3198e-04
# Epoch 75: val_loss did not improve from 0.00051
# 32/32 [==============================] - 1s 28ms/step - loss: 1.3198e-04 - val_loss: 0.0011
# Epoch 76/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.2398e-04
# Epoch 76: val_loss did not improve from 0.00051
# 32/32 [==============================] - 1s 29ms/step - loss: 1.2143e-04 - val_loss: 6.6663e-04
# Epoch 77/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.3275e-04
# Epoch 77: val_loss did not improve from 0.00051
# 32/32 [==============================] - 1s 29ms/step - loss: 1.3239e-04 - val_loss: 7.3403e-04
# Epoch 78/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.1281e-04
# Epoch 78: val_loss did not improve from 0.00051
# 32/32 [==============================] - 1s 29ms/step - loss: 1.1244e-04 - val_loss: 5.6227e-04
# Epoch 79/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.1579e-04
# Epoch 79: val_loss did not improve from 0.00051
# 32/32 [==============================] - 1s 28ms/step - loss: 1.1411e-04 - val_loss: 5.5936e-04
# Epoch 80/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.2322e-04
# Epoch 80: val_loss did not improve from 0.00051
# 32/32 [==============================] - 1s 28ms/step - loss: 1.2601e-04 - val_loss: 5.9172e-04
# Epoch 81/100
# 32/32 [==============================] - ETA: 0s - loss: 1.6481e-04
# Epoch 81: val_loss improved from 0.00051 to 0.00048, saving model to best_model.h5
# 32/32 [==============================] - 1s 29ms/step - loss: 1.6481e-04 - val_loss: 4.7749e-04
# Epoch 82/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.1824e-04
# Epoch 82: val_loss did not improve from 0.00048
# 32/32 [==============================] - 1s 29ms/step - loss: 1.2072e-04 - val_loss: 4.7908e-04
# Epoch 83/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.5597e-04
# Epoch 83: val_loss did not improve from 0.00048
# 32/32 [==============================] - 1s 29ms/step - loss: 1.5508e-04 - val_loss: 7.8477e-04
# Epoch 84/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.8667e-04
# Epoch 84: val_loss improved from 0.00048 to 0.00046, saving model to best_model.h5
# 32/32 [==============================] - 1s 30ms/step - loss: 1.8665e-04 - val_loss: 4.6460e-04
# Epoch 85/100
# 32/32 [==============================] - ETA: 0s - loss: 1.2623e-04
# Epoch 85: val_loss did not improve from 0.00046
# 32/32 [==============================] - 1s 29ms/step - loss: 1.2623e-04 - val_loss: 5.1106e-04
# Epoch 86/100
# 32/32 [==============================] - ETA: 0s - loss: 1.0749e-04
# Epoch 86: val_loss did not improve from 0.00046
# 32/32 [==============================] - 1s 29ms/step - loss: 1.0749e-04 - val_loss: 9.4054e-04
# Epoch 87/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.3049e-04
# Epoch 87: val_loss improved from 0.00046 to 0.00045, saving model to best_model.h5
# 32/32 [==============================] - 1s 29ms/step - loss: 1.2789e-04 - val_loss: 4.5427e-04
# Epoch 88/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.1523e-04
# Epoch 88: val_loss did not improve from 0.00045
# 32/32 [==============================] - 1s 29ms/step - loss: 1.1546e-04 - val_loss: 8.8155e-04
# Epoch 89/100
# 30/32 [===========================>..] - ETA: 0s - loss: 1.4389e-04
# Epoch 89: val_loss did not improve from 0.00045
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4366e-04 - val_loss: 6.5704e-04
# Epoch 90/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.3260e-04
# Epoch 90: val_loss improved from 0.00045 to 0.00045, saving model to best_model.h5
# 32/32 [==============================] - 1s 29ms/step - loss: 1.3232e-04 - val_loss: 4.5221e-04
# Epoch 91/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.1060e-04
# Epoch 91: val_loss did not improve from 0.00045
# 32/32 [==============================] - 1s 31ms/step - loss: 1.1021e-04 - val_loss: 7.2502e-04
# Epoch 92/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.1194e-04
# Epoch 92: val_loss did not improve from 0.00045
# 32/32 [==============================] - 1s 32ms/step - loss: 1.1157e-04 - val_loss: 5.4182e-04
# Epoch 93/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.0901e-04
# Epoch 93: val_loss did not improve from 0.00045
# 32/32 [==============================] - 1s 31ms/step - loss: 1.0881e-04 - val_loss: 4.6955e-04
# Epoch 94/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.0233e-04
# Epoch 94: val_loss did not improve from 0.00045
# 32/32 [==============================] - 1s 32ms/step - loss: 1.0333e-04 - val_loss: 5.6315e-04
# Epoch 95/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.4795e-04
# Epoch 95: val_loss did not improve from 0.00045
# 32/32 [==============================] - 1s 32ms/step - loss: 1.4764e-04 - val_loss: 5.2675e-04
# Epoch 96/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.2592e-04
# Epoch 96: val_loss did not improve from 0.00045
# 32/32 [==============================] - 1s 32ms/step - loss: 1.2550e-04 - val_loss: 8.0012e-04
# Epoch 97/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.2737e-04
# Epoch 97: val_loss did not improve from 0.00045
# 32/32 [==============================] - 1s 34ms/step - loss: 1.2770e-04 - val_loss: 6.3262e-04
# Epoch 98/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.0751e-04
# Epoch 98: val_loss did not improve from 0.00045
# 32/32 [==============================] - 1s 34ms/step - loss: 1.0734e-04 - val_loss: 4.6625e-04
# Epoch 99/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.1554e-04
# Epoch 99: val_loss improved from 0.00045 to 0.00043, saving model to best_model.h5
# 32/32 [==============================] - 1s 33ms/step - loss: 1.1609e-04 - val_loss: 4.2921e-04
# Epoch 100/100
# 31/32 [============================>.] - ETA: 0s - loss: 1.0315e-04
# Epoch 100: val_loss did not improve from 0.00043
# 32/32 [==============================] - 1s 30ms/step - loss: 1.0302e-04 - val_loss: 5.6889e-04

# %%
plt.plot(history.history['val_loss'])
plt.title('Validation loss vs. epochs')
# Out:
# Text(0.5, 1.0, 'Validation loss vs. epochs')

# %%
# load the saved model
from tensorflow.keras.models import load_model
model = load_model('best_model.h5')

# %%
# get predictions for test set
test_predict = model.predict(test_X)
# transform the values to contain the same values range as testy data contains
test_predict_transformed = scaler.inverse_transform(test_predict)
# get predictions for train set
train_predict = model.predict(train_X)
train_predict_transformed = scaler.inverse_transform(train_predict)
# Out:
# 13/13 [==============================] - 1s 8ms/step
# 32/32 [==============================] - 0s 8ms/step

# %%
from sklearn.metrics import mean_squared_error

# %%
print('Train MSE:', np.sqrt(mean_squared_error(trainy, train_predict_transformed)))
print('Test MSE:', np.sqrt(mean_squared_error(testy,  test_predict_transformed)))
# Out:
# Train MSE: 143.98500009822843
# Test MSE: 280.6644792786687

# %%
len(train_set), len(train_X), len(trainy), len(train_predict_transformed)
# Out:
# (1057, 996, 996, 996)

# %%
len(test_set), len(test_X), len(testy), len(test_predict_transformed)
# Out:
# (453, 392, 392, 392)

# %%
plt.plot(scaler.inverse_transform(trainx))
plt.plot(train_predict_transformed);

# %%
plt.plot(scaler.inverse_transform(testx))
plt.plot(test_predict_transformed);

# %%
### Plotting 
# shift train predictions for plotting
look_back=60
trainPredictPlot = np.empty_like(scaled_data)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict_transformed)+look_back, :] = train_predict_transformed

# shift test predictions for plotting
testPredictPlot = np.empty_like(scaled_data)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict_transformed)+(look_back*2)+1:len(scaled_data)-1, :] = test_predict_transformed

# plot baseline and predictions
plt.figure(figsize=(12,6))
plt.plot(scaler.inverse_transform(scaled_data), linewidth=1.7, label='Original data')
plt.plot(trainPredictPlot, linewidth=1.7, label='Prediction made on train data')
plt.plot(testPredictPlot, linewidth=1.7, label='Prediction made on test data')
plt.title('Microsoft Stock Price Prediction')
plt.xlabel('Datetime')
plt.ylabel('Stock Price in USD ($)')
plt.legend()
plt.show()

# %%
testy.shape, ytest.shape, ypredicted.shape, test_predict.shape
# Out:
# ((392,), (453,), (453,), (392, 1))

# %%
pd.Series(test_predict.reshape(1,-1)[0])
# Out:
# 0      0.724747
# 1      0.721373
# 2      0.727828
# 3      0.737926
# 4      0.740468
#          ...
# 387    0.578067
# 388    0.585849
# 389    0.595673
# 390    0.615545
# 391    0.630964
# Length: 392, dtype: float32

# %%
df_lstm = pd.DataFrame({'Actual': pd.Series(testy), 'Predicted': pd.Series(test_predict.reshape(1,-1)[0])})
df_lstm.head()
# Out:
#      Actual  Predicted
# 0  0.721912   0.724747
# 1  0.735088   0.721373
# 2  0.744632   0.727828
# 3  0.742851   0.737926
# 4  0.745344   0.740468

# %%
plt.plot(df_lstm['Actual'], color='green', linewidth=2)
plt.plot(df_lstm['Predicted'], color='yellow', linewidth=2)

# %%
df_lstm[-20:].plot(kind='bar', figsize=(12,7))
# Out:
# <AxesSubplot:>

# %%
# plt.figure(figsize=(12,6))

# plt.plot(scaler.inverse_transform(scaled_data), color='green')
# plt.plot(train_predict_transformed, color='yellow', linewidth=1.5, label='Predicted stock price train data')
# plt.plot(test_predict_transformed, color='red', linewidth=1.5, label='Predicted stock price test data')

# plt.plot(trainy, color='green', linewidth=2,  label='Actual stock price train data');
# plt.xticks(pd.date_range('2017-01-18', '2023-01-17', freq='Y'), rotation=45);
# # plt.plot(testy, color='blue', linewidth=2, label='Actual stock price test data')

# plt.title('Microsoft Stock Price Prediction')
# plt.xlabel('Datetime')
# plt.ylabel('Microsoft stock price')
# plt.legend()

# %%
data.index.min(), data.index.max()
# Out:
# (Timestamp('2017-01-18 00:00:00'), Timestamp('2023-01-17 00:00:00'))

# %%
test_set.shape, train_set.shape, trainx.shape, testy.shape, test_predict.shape
# Out:
# ((453, 1), (1057, 1), (996, 60), (392,), (392, 1))

# %%
df_lstm.shape
# Out:
# (392, 2)

# %%
1057-996, 453-392
# Out:
# (61, 61)

# %%
test_set[392:].shape
# Out:
# (61, 1)

# %%
test_set[392:].reshape(1,-1).shape
# Out:
# (1, 61)

# %%
# forecasting stock closing price on 2023-01-18
# we spllited the train test data in such a way that to predict the tommowow's stock price our model 
# needs the previous 60 days data

input_18 = test_set[392:].reshape(1, -1)
temp_input = input_18.tolist()[0]

# %%
len(temp_input)
# Out:
# 61

# %%
# demonstrate prediction for next 10 days
from numpy import array

lst_output=[]
n_steps=60
i=0
while(i<30):
    
    if(len(temp_input)>60):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input= x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
    

print(lst_output)
# Out:
# 0 day input [0.6191019  0.64036183 0.65863043 0.67077388 0.6019017  0.58562733
#  0.61810478 0.60478621 0.59068412 0.56194585 0.54111324 0.56653968
#  0.58961577 0.5931769  0.57765038 0.6434244  0.65813187 0.63833201
#  0.63982768 0.63897299 0.63879493 0.63715684 0.64011258 0.65072472
#  0.65980561 0.65948512 0.63907982 0.63398744 0.68672771 0.68512522
#  0.6863004  0.66913574 0.65104521 0.64837436 0.65916457 0.65211356
#  0.67736194 0.69306657 0.69413487 0.66489799 0.64951395 0.63441475
#  0.6392223  0.64858802 0.62636662 0.62828961 0.62198646 0.61333289
#  0.63640898 0.63217128 0.63131659 0.59399599 0.56981591 0.57914605
#  0.58694492 0.59310571 0.6177487  0.62750616 0.63007017 0.63405867]
# 0 day output [[0.63935804]]
# 1 day input [0.64036183 0.65863043 0.67077388 0.6019017  0.58562733 0.61810478
#  0.60478621 0.59068412 0.56194585 0.54111324 0.56653968 0.58961577
#  0.5931769  0.57765038 0.6434244  0.65813187 0.63833201 0.63982768
#  0.63897299 0.63879493 0.63715684 0.64011258 0.65072472 0.65980561
#  0.65948512 0.63907982 0.63398744 0.68672771 0.68512522 0.6863004
#  0.66913574 0.65104521 0.64837436 0.65916457 0.65211356 0.67736194
#  0.69306657 0.69413487 0.66489799 0.64951395 0.63441475 0.6392223
#  0.64858802 0.62636662 0.62828961 0.62198646 0.61333289 0.63640898
#  0.63217128 0.63131659 0.59399599 0.56981591 0.57914605 0.58694492
#  0.59310571 0.6177487  0.62750616 0.63007017 0.63405867 0.63935804]
# 1 day output [[0.642221]]
# 2 day input [0.65863043 0.67077388 0.6019017  0.58562733 0.61810478 0.60478621
#  0.59068412 0.56194585 0.54111324 0.56653968 0.58961577 0.5931769
#  0.57765038 0.6434244  0.65813187 0.63833201 0.63982768 0.63897299
#  0.63879493 0.63715684 0.64011258 0.65072472 0.65980561 0.65948512
#  0.63907982 0.63398744 0.68672771 0.68512522 0.6863004  0.66913574
#  0.65104521 0.64837436 0.65916457 0.65211356 0.67736194 0.69306657
#  0.69413487 0.66489799 0.64951395 0.63441475 0.6392223  0.64858802
#  0.62636662 0.62828961 0.62198646 0.61333289 0.63640898 0.63217128
#  0.63131659 0.59399599 0.56981591 0.57914605 0.58694492 0.59310571
#  0.6177487  0.62750616 0.63007017 0.63405867 0.63935804 0.64222097]
# 2 day output [[0.64469016]]
# 3 day input [0.67077388 0.6019017  0.58562733 0.61810478 0.60478621 0.59068412
#  0.56194585 0.54111324 0.56653968 0.58961577 0.5931769  0.57765038
#  0.6434244  0.65813187 0.63833201 0.63982768 0.63897299 0.63879493
#  0.63715684 0.64011258 0.65072472 0.65980561 0.65948512 0.63907982
#  0.63398744 0.68672771 0.68512522 0.6863004  0.66913574 0.65104521
#  0.64837436 0.65916457 0.65211356 0.67736194 0.69306657 0.69413487
#  0.66489799 0.64951395 0.63441475 0.6392223  0.64858802 0.62636662
#  0.62828961 0.62198646 0.61333289 0.63640898 0.63217128 0.63131659
#  0.59399599 0.56981591 0.57914605 0.58694492 0.59310571 0.6177487
#  0.62750616 0.63007017 0.63405867 0.63935804 0.64222097 0.64469016]
# 3 day output [[0.6467653]]
# 4 day input [0.6019017  0.58562733 0.61810478 0.60478621 0.59068412 0.56194585
#  0.54111324 0.56653968 0.58961577 0.5931769  0.57765038 0.6434244
#  0.65813187 0.63833201 0.63982768 0.63897299 0.63879493 0.63715684
#  0.64011258 0.65072472 0.65980561 0.65948512 0.63907982 0.63398744
#  0.68672771 0.68512522 0.6863004  0.66913574 0.65104521 0.64837436
#  0.65916457 0.65211356 0.67736194 0.69306657 0.69413487 0.66489799
#  0.64951395 0.63441475 0.6392223  0.64858802 0.62636662 0.62828961
#  0.62198646 0.61333289 0.63640898 0.63217128 0.63131659 0.59399599
#  0.56981591 0.57914605 0.58694492 0.59310571 0.6177487  0.62750616
#  0.63007017 0.63405867 0.63935804 0.64222097 0.64469016 0.64676529]
# 4 day output [[0.6485424]]
# 5 day input [0.58562733 0.61810478 0.60478621 0.59068412 0.56194585 0.54111324
#  0.56653968 0.58961577 0.5931769  0.57765038 0.6434244  0.65813187
#  0.63833201 0.63982768 0.63897299 0.63879493 0.63715684 0.64011258
#  0.65072472 0.65980561 0.65948512 0.63907982 0.63398744 0.68672771
#  0.68512522 0.6863004  0.66913574 0.65104521 0.64837436 0.65916457
#  0.65211356 0.67736194 0.69306657 0.69413487 0.66489799 0.64951395
#  0.63441475 0.6392223  0.64858802 0.62636662 0.62828961 0.62198646
#  0.61333289 0.63640898 0.63217128 0.63131659 0.59399599 0.56981591
#  0.57914605 0.58694492 0.59310571 0.6177487  0.62750616 0.63007017
#  0.63405867 0.63935804 0.64222097 0.64469016 0.64676529 0.6485424 ]
# 5 day output [[0.65009004]]
# 6 day input [0.61810478 0.60478621 0.59068412 0.56194585 0.54111324 0.56653968
#  0.58961577 0.5931769  0.57765038 0.6434244  0.65813187 0.63833201
#  0.63982768 0.63897299 0.63879493 0.63715684 0.64011258 0.65072472
#  0.65980561 0.65948512 0.63907982 0.63398744 0.68672771 0.68512522
#  0.6863004  0.66913574 0.65104521 0.64837436 0.65916457 0.65211356
#  0.67736194 0.69306657 0.69413487 0.66489799 0.64951395 0.63441475
#  0.6392223  0.64858802 0.62636662 0.62828961 0.62198646 0.61333289
#  0.63640898 0.63217128 0.63131659 0.59399599 0.56981591 0.57914605
#  0.58694492 0.59310571 0.6177487  0.62750616 0.63007017 0.63405867
#  0.63935804 0.64222097 0.64469016 0.64676529 0.6485424  0.65009004]
# 6 day output [[0.6514391]]
# 7 day input [0.60478621 0.59068412 0.56194585 0.54111324 0.56653968 0.58961577
#  0.5931769  0.57765038 0.6434244  0.65813187 0.63833201 0.63982768
#  0.63897299 0.63879493 0.63715684 0.64011258 0.65072472 0.65980561
#  0.65948512 0.63907982 0.63398744 0.68672771 0.68512522 0.6863004
#  0.66913574 0.65104521 0.64837436 0.65916457 0.65211356 0.67736194
#  0.69306657 0.69413487 0.66489799 0.64951395 0.63441475 0.6392223
#  0.64858802 0.62636662 0.62828961 0.62198646 0.61333289 0.63640898
#  0.63217128 0.63131659 0.59399599 0.56981591 0.57914605 0.58694492
#  0.59310571 0.6177487  0.62750616 0.63007017 0.63405867 0.63935804
#  0.64222097 0.64469016 0.64676529 0.6485424  0.65009004 0.65143907]
# 7 day output [[0.65260005]]
# 8 day input [0.59068412 0.56194585 0.54111324 0.56653968 0.58961577 0.5931769
#  0.57765038 0.6434244  0.65813187 0.63833201 0.63982768 0.63897299
#  0.63879493 0.63715684 0.64011258 0.65072472 0.65980561 0.65948512
#  0.63907982 0.63398744 0.68672771 0.68512522 0.6863004  0.66913574
#  0.65104521 0.64837436 0.65916457 0.65211356 0.67736194 0.69306657
#  0.69413487 0.66489799 0.64951395 0.63441475 0.6392223  0.64858802
#  0.62636662 0.62828961 0.62198646 0.61333289 0.63640898 0.63217128
#  0.63131659 0.59399599 0.56981591 0.57914605 0.58694492 0.59310571
#  0.6177487  0.62750616 0.63007017 0.63405867 0.63935804 0.64222097
#  0.64469016 0.64676529 0.6485424  0.65009004 0.65143907 0.65260005]
# 8 day output [[0.65358037]]
# 9 day input [0.56194585 0.54111324 0.56653968 0.58961577 0.5931769  0.57765038
#  0.6434244  0.65813187 0.63833201 0.63982768 0.63897299 0.63879493
#  0.63715684 0.64011258 0.65072472 0.65980561 0.65948512 0.63907982
#  0.63398744 0.68672771 0.68512522 0.6863004  0.66913574 0.65104521
#  0.64837436 0.65916457 0.65211356 0.67736194 0.69306657 0.69413487
#  0.66489799 0.64951395 0.63441475 0.6392223  0.64858802 0.62636662
#  0.62828961 0.62198646 0.61333289 0.63640898 0.63217128 0.63131659
#  0.59399599 0.56981591 0.57914605 0.58694492 0.59310571 0.6177487
#  0.62750616 0.63007017 0.63405867 0.63935804 0.64222097 0.64469016
#  0.64676529 0.6485424  0.65009004 0.65143907 0.65260005 0.65358037]
# 9 day output [[0.65438545]]
# 10 day input [0.54111324 0.56653968 0.58961577 0.5931769  0.57765038 0.6434244
#  0.65813187 0.63833201 0.63982768 0.63897299 0.63879493 0.63715684
#  0.64011258 0.65072472 0.65980561 0.65948512 0.63907982 0.63398744
#  0.68672771 0.68512522 0.6863004  0.66913574 0.65104521 0.64837436
#  0.65916457 0.65211356 0.67736194 0.69306657 0.69413487 0.66489799
#  0.64951395 0.63441475 0.6392223  0.64858802 0.62636662 0.62828961
#  0.62198646 0.61333289 0.63640898 0.63217128 0.63131659 0.59399599
#  0.56981591 0.57914605 0.58694492 0.59310571 0.6177487  0.62750616
#  0.63007017 0.63405867 0.63935804 0.64222097 0.64469016 0.64676529
#  0.6485424  0.65009004 0.65143907 0.65260005 0.65358037 0.65438545]
# 10 day output [[0.65502536]]
# 11 day input [0.56653968 0.58961577 0.5931769  0.57765038 0.6434244  0.65813187
#  0.63833201 0.63982768 0.63897299 0.63879493 0.63715684 0.64011258
#  0.65072472 0.65980561 0.65948512 0.63907982 0.63398744 0.68672771
#  0.68512522 0.6863004  0.66913574 0.65104521 0.64837436 0.65916457
#  0.65211356 0.67736194 0.69306657 0.69413487 0.66489799 0.64951395
#  0.63441475 0.6392223  0.64858802 0.62636662 0.62828961 0.62198646
#  0.61333289 0.63640898 0.63217128 0.63131659 0.59399599 0.56981591
#  0.57914605 0.58694492 0.59310571 0.6177487  0.62750616 0.63007017
#  0.63405867 0.63935804 0.64222097 0.64469016 0.64676529 0.6485424
#  0.65009004 0.65143907 0.65260005 0.65358037 0.65438545 0.65502536]
# 11 day output [[0.6555148]]
# 12 day input [0.58961577 0.5931769  0.57765038 0.6434244  0.65813187 0.63833201
#  0.63982768 0.63897299 0.63879493 0.63715684 0.64011258 0.65072472
#  0.65980561 0.65948512 0.63907982 0.63398744 0.68672771 0.68512522
#  0.6863004  0.66913574 0.65104521 0.64837436 0.65916457 0.65211356
#  0.67736194 0.69306657 0.69413487 0.66489799 0.64951395 0.63441475
#  0.6392223  0.64858802 0.62636662 0.62828961 0.62198646 0.61333289
#  0.63640898 0.63217128 0.63131659 0.59399599 0.56981591 0.57914605
#  0.58694492 0.59310571 0.6177487  0.62750616 0.63007017 0.63405867
#  0.63935804 0.64222097 0.64469016 0.64676529 0.6485424  0.65009004
#  0.65143907 0.65260005 0.65358037 0.65438545 0.65502536 0.65551478]
# 12 day output [[0.6558707]]
# 13 day input [0.5931769  0.57765038 0.6434244  0.65813187 0.63833201 0.63982768
#  0.63897299 0.63879493 0.63715684 0.64011258 0.65072472 0.65980561
#  0.65948512 0.63907982 0.63398744 0.68672771 0.68512522 0.6863004
#  0.66913574 0.65104521 0.64837436 0.65916457 0.65211356 0.67736194
#  0.69306657 0.69413487 0.66489799 0.64951395 0.63441475 0.6392223
#  0.64858802 0.62636662 0.62828961 0.62198646 0.61333289 0.63640898
#  0.63217128 0.63131659 0.59399599 0.56981591 0.57914605 0.58694492
#  0.59310571 0.6177487  0.62750616 0.63007017 0.63405867 0.63935804
#  0.64222097 0.64469016 0.64676529 0.6485424  0.65009004 0.65143907
#  0.65260005 0.65358037 0.65438545 0.65502536 0.65551478 0.65587068]
# 13 day output [[0.6561148]]
# 14 day input [0.57765038 0.6434244  0.65813187 0.63833201 0.63982768 0.63897299
#  0.63879493 0.63715684 0.64011258 0.65072472 0.65980561 0.65948512
#  0.63907982 0.63398744 0.68672771 0.68512522 0.6863004  0.66913574
#  0.65104521 0.64837436 0.65916457 0.65211356 0.67736194 0.69306657
#  0.69413487 0.66489799 0.64951395 0.63441475 0.6392223  0.64858802
#  0.62636662 0.62828961 0.62198646 0.61333289 0.63640898 0.63217128
#  0.63131659 0.59399599 0.56981591 0.57914605 0.58694492 0.59310571
#  0.6177487  0.62750616 0.63007017 0.63405867 0.63935804 0.64222097
#  0.64469016 0.64676529 0.6485424  0.65009004 0.65143907 0.65260005
#  0.65358037 0.65438545 0.65502536 0.65551478 0.65587068 0.65611482]
# 14 day output [[0.65627235]]
# 15 day input [0.6434244  0.65813187 0.63833201 0.63982768 0.63897299 0.63879493
#  0.63715684 0.64011258 0.65072472 0.65980561 0.65948512 0.63907982
#  0.63398744 0.68672771 0.68512522 0.6863004  0.66913574 0.65104521
#  0.64837436 0.65916457 0.65211356 0.67736194 0.69306657 0.69413487
#  0.66489799 0.64951395 0.63441475 0.6392223  0.64858802 0.62636662
#  0.62828961 0.62198646 0.61333289 0.63640898 0.63217128 0.63131659
#  0.59399599 0.56981591 0.57914605 0.58694492 0.59310571 0.6177487
#  0.62750616 0.63007017 0.63405867 0.63935804 0.64222097 0.64469016
#  0.64676529 0.6485424  0.65009004 0.65143907 0.65260005 0.65358037
#  0.65438545 0.65502536 0.65551478 0.65587068 0.65611482 0.65627235]
# 15 day output [[0.65636903]]
# 16 day input [0.65813187 0.63833201 0.63982768 0.63897299 0.63879493 0.63715684
#  0.64011258 0.65072472 0.65980561 0.65948512 0.63907982 0.63398744
#  0.68672771 0.68512522 0.6863004  0.66913574 0.65104521 0.64837436
#  0.65916457 0.65211356 0.67736194 0.69306657 0.69413487 0.66489799
#  0.64951395 0.63441475 0.6392223  0.64858802 0.62636662 0.62828961
#  0.62198646 0.61333289 0.63640898 0.63217128 0.63131659 0.59399599
#  0.56981591 0.57914605 0.58694492 0.59310571 0.6177487  0.62750616
#  0.63007017 0.63405867 0.63935804 0.64222097 0.64469016 0.64676529
#  0.6485424  0.65009004 0.65143907 0.65260005 0.65358037 0.65438545
#  0.65502536 0.65551478 0.65587068 0.65611482 0.65627235 0.65636903]
# 16 day output [[0.6564239]]
# 17 day input [0.63833201 0.63982768 0.63897299 0.63879493 0.63715684 0.64011258
#  0.65072472 0.65980561 0.65948512 0.63907982 0.63398744 0.68672771
#  0.68512522 0.6863004  0.66913574 0.65104521 0.64837436 0.65916457
#  0.65211356 0.67736194 0.69306657 0.69413487 0.66489799 0.64951395
#  0.63441475 0.6392223  0.64858802 0.62636662 0.62828961 0.62198646
#  0.61333289 0.63640898 0.63217128 0.63131659 0.59399599 0.56981591
#  0.57914605 0.58694492 0.59310571 0.6177487  0.62750616 0.63007017
#  0.63405867 0.63935804 0.64222097 0.64469016 0.64676529 0.6485424
#  0.65009004 0.65143907 0.65260005 0.65358037 0.65438545 0.65502536
#  0.65551478 0.65587068 0.65611482 0.65627235 0.65636903 0.65642393]
# 17 day output [[0.6564602]]
# 18 day input [0.63982768 0.63897299 0.63879493 0.63715684 0.64011258 0.65072472
#  0.65980561 0.65948512 0.63907982 0.63398744 0.68672771 0.68512522
#  0.6863004  0.66913574 0.65104521 0.64837436 0.65916457 0.65211356
#  0.67736194 0.69306657 0.69413487 0.66489799 0.64951395 0.63441475
#  0.6392223  0.64858802 0.62636662 0.62828961 0.62198646 0.61333289
#  0.63640898 0.63217128 0.63131659 0.59399599 0.56981591 0.57914605
#  0.58694492 0.59310571 0.6177487  0.62750616 0.63007017 0.63405867
#  0.63935804 0.64222097 0.64469016 0.64676529 0.6485424  0.65009004
#  0.65143907 0.65260005 0.65358037 0.65438545 0.65502536 0.65551478
#  0.65587068 0.65611482 0.65627235 0.65636903 0.65642393 0.65646023]
# 18 day output [[0.6564982]]
# 19 day input [0.63897299 0.63879493 0.63715684 0.64011258 0.65072472 0.65980561
#  0.65948512 0.63907982 0.63398744 0.68672771 0.68512522 0.6863004
#  0.66913574 0.65104521 0.64837436 0.65916457 0.65211356 0.67736194
#  0.69306657 0.69413487 0.66489799 0.64951395 0.63441475 0.6392223
#  0.64858802 0.62636662 0.62828961 0.62198646 0.61333289 0.63640898
#  0.63217128 0.63131659 0.59399599 0.56981591 0.57914605 0.58694492
#  0.59310571 0.6177487  0.62750616 0.63007017 0.63405867 0.63935804
#  0.64222097 0.64469016 0.64676529 0.6485424  0.65009004 0.65143907
#  0.65260005 0.65358037 0.65438545 0.65502536 0.65551478 0.65587068
#  0.65611482 0.65627235 0.65636903 0.65642393 0.65646023 0.65649819]
# 19 day output [[0.65655285]]
# 20 day input [0.63879493 0.63715684 0.64011258 0.65072472 0.65980561 0.65948512
#  0.63907982 0.63398744 0.68672771 0.68512522 0.6863004  0.66913574
#  0.65104521 0.64837436 0.65916457 0.65211356 0.67736194 0.69306657
#  0.69413487 0.66489799 0.64951395 0.63441475 0.6392223  0.64858802
#  0.62636662 0.62828961 0.62198646 0.61333289 0.63640898 0.63217128
#  0.63131659 0.59399599 0.56981591 0.57914605 0.58694492 0.59310571
#  0.6177487  0.62750616 0.63007017 0.63405867 0.63935804 0.64222097
#  0.64469016 0.64676529 0.6485424  0.65009004 0.65143907 0.65260005
#  0.65358037 0.65438545 0.65502536 0.65551478 0.65587068 0.65611482
#  0.65627235 0.65636903 0.65642393 0.65646023 0.65649819 0.65655285]
# 20 day output [[0.6566373]]
# 21 day input [0.63715684 0.64011258 0.65072472 0.65980561 0.65948512 0.63907982
#  0.63398744 0.68672771 0.68512522 0.6863004  0.66913574 0.65104521
#  0.64837436 0.65916457 0.65211356 0.67736194 0.69306657 0.69413487
#  0.66489799 0.64951395 0.63441475 0.6392223  0.64858802 0.62636662
#  0.62828961 0.62198646 0.61333289 0.63640898 0.63217128 0.63131659
#  0.59399599 0.56981591 0.57914605 0.58694492 0.59310571 0.6177487
#  0.62750616 0.63007017 0.63405867 0.63935804 0.64222097 0.64469016
#  0.64676529 0.6485424  0.65009004 0.65143907 0.65260005 0.65358037
#  0.65438545 0.65502536 0.65551478 0.65587068 0.65611482 0.65627235
#  0.65636903 0.65642393 0.65646023 0.65649819 0.65655285 0.65663731]
# 21 day output [[0.65676075]]
# 22 day input [0.64011258 0.65072472 0.65980561 0.65948512 0.63907982 0.63398744
#  0.68672771 0.68512522 0.6863004  0.66913574 0.65104521 0.64837436
#  0.65916457 0.65211356 0.67736194 0.69306657 0.69413487 0.66489799
#  0.64951395 0.63441475 0.6392223  0.64858802 0.62636662 0.62828961
#  0.62198646 0.61333289 0.63640898 0.63217128 0.63131659 0.59399599
#  0.56981591 0.57914605 0.58694492 0.59310571 0.6177487  0.62750616
#  0.63007017 0.63405867 0.63935804 0.64222097 0.64469016 0.64676529
#  0.6485424  0.65009004 0.65143907 0.65260005 0.65358037 0.65438545
#  0.65502536 0.65551478 0.65587068 0.65611482 0.65627235 0.65636903
#  0.65642393 0.65646023 0.65649819 0.65655285 0.65663731 0.65676075]
# 22 day output [[0.65692997]]
# 23 day input [0.65072472 0.65980561 0.65948512 0.63907982 0.63398744 0.68672771
#  0.68512522 0.6863004  0.66913574 0.65104521 0.64837436 0.65916457
#  0.65211356 0.67736194 0.69306657 0.69413487 0.66489799 0.64951395
#  0.63441475 0.6392223  0.64858802 0.62636662 0.62828961 0.62198646
#  0.61333289 0.63640898 0.63217128 0.63131659 0.59399599 0.56981591
#  0.57914605 0.58694492 0.59310571 0.6177487  0.62750616 0.63007017
#  0.63405867 0.63935804 0.64222097 0.64469016 0.64676529 0.6485424
#  0.65009004 0.65143907 0.65260005 0.65358037 0.65438545 0.65502536
#  0.65551478 0.65587068 0.65611482 0.65627235 0.65636903 0.65642393
#  0.65646023 0.65649819 0.65655285 0.65663731 0.65676075 0.65692997]
# 23 day output [[0.6571484]]
# 24 day input [0.65980561 0.65948512 0.63907982 0.63398744 0.68672771 0.68512522
#  0.6863004  0.66913574 0.65104521 0.64837436 0.65916457 0.65211356
#  0.67736194 0.69306657 0.69413487 0.66489799 0.64951395 0.63441475
#  0.6392223  0.64858802 0.62636662 0.62828961 0.62198646 0.61333289
#  0.63640898 0.63217128 0.63131659 0.59399599 0.56981591 0.57914605
#  0.58694492 0.59310571 0.6177487  0.62750616 0.63007017 0.63405867
#  0.63935804 0.64222097 0.64469016 0.64676529 0.6485424  0.65009004
#  0.65143907 0.65260005 0.65358037 0.65438545 0.65502536 0.65551478
#  0.65587068 0.65611482 0.65627235 0.65636903 0.65642393 0.65646023
#  0.65649819 0.65655285 0.65663731 0.65676075 0.65692997 0.65714842]
# 24 day output [[0.6574172]]
# 25 day input [0.65948512 0.63907982 0.63398744 0.68672771 0.68512522 0.6863004
#  0.66913574 0.65104521 0.64837436 0.65916457 0.65211356 0.67736194
#  0.69306657 0.69413487 0.66489799 0.64951395 0.63441475 0.6392223
#  0.64858802 0.62636662 0.62828961 0.62198646 0.61333289 0.63640898
#  0.63217128 0.63131659 0.59399599 0.56981591 0.57914605 0.58694492
#  0.59310571 0.6177487  0.62750616 0.63007017 0.63405867 0.63935804
#  0.64222097 0.64469016 0.64676529 0.6485424  0.65009004 0.65143907
#  0.65260005 0.65358037 0.65438545 0.65502536 0.65551478 0.65587068
#  0.65611482 0.65627235 0.65636903 0.65642393 0.65646023 0.65649819
#  0.65655285 0.65663731 0.65676075 0.65692997 0.65714842 0.65741718]
# 25 day output [[0.6577357]]
# 26 day input [0.63907982 0.63398744 0.68672771 0.68512522 0.6863004  0.66913574
#  0.65104521 0.64837436 0.65916457 0.65211356 0.67736194 0.69306657
#  0.69413487 0.66489799 0.64951395 0.63441475 0.6392223  0.64858802
#  0.62636662 0.62828961 0.62198646 0.61333289 0.63640898 0.63217128
#  0.63131659 0.59399599 0.56981591 0.57914605 0.58694492 0.59310571
#  0.6177487  0.62750616 0.63007017 0.63405867 0.63935804 0.64222097
#  0.64469016 0.64676529 0.6485424  0.65009004 0.65143907 0.65260005
#  0.65358037 0.65438545 0.65502536 0.65551478 0.65587068 0.65611482
#  0.65627235 0.65636903 0.65642393 0.65646023 0.65649819 0.65655285
#  0.65663731 0.65676075 0.65692997 0.65714842 0.65741718 0.65773571]
# 26 day output [[0.6581023]]
# 27 day input [0.63398744 0.68672771 0.68512522 0.6863004  0.66913574 0.65104521
#  0.64837436 0.65916457 0.65211356 0.67736194 0.69306657 0.69413487
#  0.66489799 0.64951395 0.63441475 0.6392223  0.64858802 0.62636662
#  0.62828961 0.62198646 0.61333289 0.63640898 0.63217128 0.63131659
#  0.59399599 0.56981591 0.57914605 0.58694492 0.59310571 0.6177487
#  0.62750616 0.63007017 0.63405867 0.63935804 0.64222097 0.64469016
#  0.64676529 0.6485424  0.65009004 0.65143907 0.65260005 0.65358037
#  0.65438545 0.65502536 0.65551478 0.65587068 0.65611482 0.65627235
#  0.65636903 0.65642393 0.65646023 0.65649819 0.65655285 0.65663731
#  0.65676075 0.65692997 0.65714842 0.65741718 0.65773571 0.65810227]
# 27 day output [[0.6585153]]
# 28 day input [0.68672771 0.68512522 0.6863004  0.66913574 0.65104521 0.64837436
#  0.65916457 0.65211356 0.67736194 0.69306657 0.69413487 0.66489799
#  0.64951395 0.63441475 0.6392223  0.64858802 0.62636662 0.62828961
#  0.62198646 0.61333289 0.63640898 0.63217128 0.63131659 0.59399599
#  0.56981591 0.57914605 0.58694492 0.59310571 0.6177487  0.62750616
#  0.63007017 0.63405867 0.63935804 0.64222097 0.64469016 0.64676529
#  0.6485424  0.65009004 0.65143907 0.65260005 0.65358037 0.65438545
#  0.65502536 0.65551478 0.65587068 0.65611482 0.65627235 0.65636903
#  0.65642393 0.65646023 0.65649819 0.65655285 0.65663731 0.65676075
#  0.65692997 0.65714842 0.65741718 0.65773571 0.65810227 0.65851527]
# 28 day output [[0.6589705]]
# 29 day input [0.68512522 0.6863004  0.66913574 0.65104521 0.64837436 0.65916457
#  0.65211356 0.67736194 0.69306657 0.69413487 0.66489799 0.64951395
#  0.63441475 0.6392223  0.64858802 0.62636662 0.62828961 0.62198646
#  0.61333289 0.63640898 0.63217128 0.63131659 0.59399599 0.56981591
#  0.57914605 0.58694492 0.59310571 0.6177487  0.62750616 0.63007017
#  0.63405867 0.63935804 0.64222097 0.64469016 0.64676529 0.6485424
#  0.65009004 0.65143907 0.65260005 0.65358037 0.65438545 0.65502536
#  0.65551478 0.65587068 0.65611482 0.65627235 0.65636903 0.65642393
#  0.65646023 0.65649819 0.65655285 0.65663731 0.65676075 0.65692997
#  0.65714842 0.65741718 0.65773571 0.65810227 0.65851527 0.65897048]
# 29 day output [[0.6594596]]
# [[0.6393580436706543], [0.6422209739685059], [0.6446901559829712], [0.6467652916908264], [0.6485424041748047], [0.6500900387763977], [0.6514390707015991], [0.6526000499725342], [0.653580367565155], [0.6543854475021362], [0.6550253629684448], [0.6555147767066956], [0.6558706760406494], [0.6561148166656494], [0.6562723517417908], [0.6563690304756165], [0.6564239263534546], [0.6564602255821228], [0.6564981937408447], [0.6565528512001038], [0.6566373109817505], [0.6567607522010803], [0.6569299697875977], [0.6571484208106995], [0.6574171781539917], [0.6577357053756714], [0.65810227394104], [0.6585152745246887], [0.6589704751968384], [0.6594595909118652]]

# %%
day_new = np.arange(1, 61)
day_pred = np.arange(61, 91)

# %%
scaled_data.shape, day_new.shape, day_pred.shape
# Out:
# ((1510, 1), (60,), (30,))

# %%
1510-60
# Out:
# 1450

# %%
plt.plot(day_new, scaler.inverse_transform(scaled_data[1450:]))
plt.plot(day_pred, scaler.inverse_transform(lst_output))

# %%
df_forecast = scaled_data.tolist()
df_forecast.extend(lst_output)
plt.plot(df_forecast[1200:])

# %%
plt.plot(df_forecast)

# %% [markdown]
# ## Is Microsoft stock worth buying in 2023?

# %%
from datetime import datetime

# %%
datetime.today()

# %%
len(df.index)

# %%
df.index.min(), df.index.max()

# %%
pd.date_range('2017-01-18', '2023-01-17', freq='B')

# %%
len(pd.date_range('2017-01-18', '2023-01-17', freq='Y'))

# %%
# closing price of microsoft at 2023-01-18
